# %%
import pandas as pd
import numpy as np
import time
import phik
import tqdm

import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

import pickle

from beartype import beartype

from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.linear_model import LogisticRegression  
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, f1_score, classification_report, roc_auc_score

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_regression, RFECV 
from category_encoders import TargetEncoder


import mlflow
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set(
    style='ticks', 
    context='talk', 
    font_scale=0.8, 
    rc={'figure.figsize': (8,6)})

# %%
# load scraped dataset
matches = pd.read_csv("../data/match_data.csv")

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 1  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 2  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 3  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 4  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 1   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 2           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 3   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 4          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#    season     team
# 0    2024  Arsenal
# 1    2024  Arsenal
# 2    2024  Arsenal
# 3    2024  Arsenal
# 4    2024  Arsenal
#
# [5 rows x 27 columns]

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4426 entries, 0 to 4425
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          4426 non-null   object
#  1   time          4426 non-null   object
#  2   comp          4426 non-null   object
#  3   round         4426 non-null   object
#  4   day           4426 non-null   object
#  5   venue         4426 non-null   object
#  6   result        4426 non-null   object
#  7   gf            4426 non-null   float64
#  8   ga            4426 non-null   float64
#  9   opponent      4426 non-null   object
#  10  xg            4426 non-null   float64
#  11  xga           4426 non-null   float64
#  12  poss          4426 non-null   float64
#  13  attendance    3544 non-null   float64
#  14  captain       4426 non-null   object
#  15  formation     4426 non-null   object
#  16  referee       4426 non-null   object
#  17  match report  4426 non-null   object
#  18  notes         0 non-null      float64
#  19  sh            4426 non-null   float64
#  20  sot           4426 non-null   float64
#  21  dist          4424 non-null   float64
#  22  fk            4426 non-null   float64
#  23  pk            4426 non-null   int64
#  24  pkatt         4426 non-null   int64
#  25  season        4426 non-null   int64
#  26  team          4426 non-null   object
# dtypes: float64(11), int64(3), object(13)
# memory usage: 933.7+ KB

# %%
# check for duplicated entries
matches[matches.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, time, comp, round, day, venue, result, gf, ga, opponent, xg, xga, poss, attendance, captain, formation, referee, match report, notes, sh, sot, dist, fk, pk, pkatt, season, team]
# Index: []
#
# [0 rows x 27 columns]

# %%
# quick check of descriptive statistics of numerical features
matches.describe().T
# Out:
#              count          mean           std     min       25%      50%  \
# gf          4426.0      1.422955      1.284609     0.0      0.00      1.0
# ga          4426.0      1.422955      1.284609     0.0      0.00      1.0
# xg          4426.0      1.379530      0.814899     0.0      0.80      1.2
# xga         4426.0      1.379530      0.814899     0.0      0.80      1.2
# poss        4426.0     50.000904     12.906110    18.0     40.00     50.0
# attendance  3544.0  38561.563205  16970.943161  2000.0  25717.25  32571.0
# notes          0.0           NaN           NaN     NaN       NaN      NaN
# sh          4426.0     12.542702      5.506656     0.0      8.25     12.0
# sot         4426.0      4.188432      2.440471     0.0      2.00      4.0
# dist        4424.0     17.381420      3.013903     5.3     15.40     17.3
# fk          4426.0      0.443742      0.660849     0.0      0.00      0.0
# pk          4426.0      0.112065      0.333587     0.0      0.00      0.0
# pkatt       4426.0      0.138048      0.369043     0.0      0.00      0.0
# season      4426.0   2021.424311      1.676501  2019.0   2020.00   2021.0
#
#                  75%      max
# gf              2.00      9.0
# ga              2.00      9.0
# xg              1.80      7.0
# xga             1.80      7.0
# poss           60.00     82.0
# attendance  53182.75  81332.0
# notes            NaN      NaN
# sh             16.00     36.0
# sot             6.00     15.0
# dist           19.10     39.9
# fk              1.00      4.0
# pk              0.00      3.0
# pkatt           0.00      3.0
# season       2023.00   2024.0

# %%
# quick check of descriptive statistics of categorical features
matches.describe(include='object').T
# Out:
#              count unique              top  freq
# date          4426    697       2021-05-23    20
# time          4426     24            15:00  1382
# comp          4426      1   Premier League  4426
# round         4426     38      Matchweek 1   120
# day           4426      7              Sat  2072
# venue         4426      2             Home  2213
# result        4426      3                W  1721
# opponent      4426     28         West Ham   222
# captain       4426    203       Lewis Dunk   183
# formation     4426     22          4-2-3-1  1188
# referee       4426     36   Anthony Taylor   344
# match report  4426      1     Match Report  4426
# team          4426     28  West Ham United   222

# %%
# number of unique values in each column
columns = matches.columns
for col in range(len(columns)):
    n_unique = matches[columns[col]].nunique()
    if n_unique > 1:
        print(f"There are {n_unique} uniques {' '.join(columns[col].split('_'))}s in {columns[col]} column")
    else:
        print(f"There is {n_unique} unique {' '.join(columns[col].split('_'))} in {columns[col]} column")
# Out:
# There are 697 uniques dates in date column
# There are 24 uniques times in time column
# There is 1 unique comp in comp column
# There are 38 uniques rounds in round column
# There are 7 uniques days in day column
# There are 2 uniques venues in venue column
# There are 3 uniques results in result column
# There are 10 uniques gfs in gf column
# There are 10 uniques gas in ga column
# There are 28 uniques opponents in opponent column
# There are 52 uniques xgs in xg column
# There are 52 uniques xgas in xga column
# There are 65 uniques posss in poss column
# There are 1632 uniques attendances in attendance column
# There are 203 uniques captains in captain column
# There are 22 uniques formations in formation column
# There are 36 uniques referees in referee column
# There is 1 unique match report in match report column
# There is 0 unique notes in notes column
# There are 35 uniques shs in sh column
# There are 16 uniques sots in sot column
# There are 195 uniques dists in dist column
# There are 5 uniques fks in fk column
# There are 4 uniques pks in pk column
# There are 4 uniques pkatts in pkatt column
# There are 6 uniques seasons in season column
# There are 28 uniques teams in team column

# %%
matches.shape
# Out:
# (4426, 27)

# %%
# proportion of missing values in the datatset
matches.isnull().sum() *100 / len(matches)
# Out:
# date              0.000000
# time              0.000000
# comp              0.000000
# round             0.000000
# day               0.000000
# venue             0.000000
# result            0.000000
# gf                0.000000
# ga                0.000000
# opponent          0.000000
# xg                0.000000
# xga               0.000000
# poss              0.000000
# attendance       19.927700
# captain           0.000000
# formation         0.000000
# referee           0.000000
# match report      0.000000
# notes           100.000000
# sh                0.000000
# sot               0.000000
# dist              0.045188
# fk                0.000000
# pk                0.000000
# pkatt             0.000000
# season            0.000000
# team              0.000000
# dtype: float64

# %% [markdown]
# Dropping the `attendance`, `comp`, `match report`,`round` columns

# %%
matches.drop(['attendance','comp','notes','match report','round','dist'], axis='columns', inplace=True)

# %%
matches.shape
# Out:
# (4426, 21)

# %%
# proportion of missing values in the datatset
matches.isnull().sum() *100 / len(matches)
# Out:
# date         0.0
# time         0.0
# day          0.0
# venue        0.0
# result       0.0
# gf           0.0
# ga           0.0
# opponent     0.0
# xg           0.0
# xga          0.0
# poss         0.0
# captain      0.0
# formation    0.0
# referee      0.0
# sh           0.0
# sot          0.0
# fk           0.0
# pk           0.0
# pkatt        0.0
# season       0.0
# team         0.0
# dtype: float64

# %%
# Drop rows with missing vlaues
matches.dropna(axis=0, inplace=True)

# %%
matches.isnull().sum()
# Out:
# date         0
# time         0
# day          0
# venue        0
# result       0
# gf           0
# ga           0
# opponent     0
# xg           0
# xga          0
# poss         0
# captain      0
# formation    0
# referee      0
# sh           0
# sot          0
# fk           0
# pk           0
# pkatt        0
# season       0
# team         0
# dtype: int64

# %%
matches.shape
# Out:
# (4426, 21)

# %%
matches.head(2)
# Out:
#          date   time  day venue result   gf   ga         opponent   xg  xga  \
# 0  2023-08-12  12:30  Sat  Home      W  2.0  1.0  Nott'ham Forest  0.8  1.2
# 1  2023-08-21  20:00  Mon  Away      W  1.0  0.0   Crystal Palace  2.0  1.0
#
#    ...          captain formation         referee    sh  sot   fk  pk  pkatt  \
# 0  ...  Martin Ødegaard     4-3-3  Michael Oliver  15.0  7.0  0.0   0      0
# 1  ...  Martin Ødegaard     4-3-3     David Coote  13.0  2.0  0.0   1      1
#
#    season     team
# 0    2024  Arsenal
# 1    2024  Arsenal
#
# [2 rows x 21 columns]

# %%
matches['team'].unique()
# Out:
# array(['Arsenal', 'Liverpool', 'Manchester City', 'Tottenham Hotspur',
#        'Aston Villa', 'Manchester United', 'West Ham United',
#        'Newcastle United', 'Chelsea', 'Brighton and Hove Albion',
#        'Wolverhampton Wanderers', 'Bournemouth', 'Fulham',
#        'Crystal Palace', 'Brentford', 'Everton', 'Nottingham Forest',
#        'Luton Town', 'Burnley', 'Sheffield United', 'Leicester City',
#        'Leeds United', 'Southampton', 'Watford', 'Norwich City',
#        'West Bromwich Albion', 'Cardiff City', 'Huddersfield Town'],
#       dtype=object)

# %%
matches['season'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019])

# %% [markdown]
# ## Exploratory Data Analysis
#
# Taking each columns that we will might give us information on target which is the match result

# %%
matches.columns
# Out:
# Index(['date', 'time', 'day', 'venue', 'result', 'gf', 'ga', 'opponent', 'xg',
#        'xga', 'poss', 'captain', 'formation', 'referee', 'sh', 'sot', 'fk',
#        'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %%
data_dict = {"date":"local match date",
                   "time":"local time for kick-off",
                   "day":"day of match",
                   "venue":"match venue",
                   "result":"match result",
                   "gf":"goal score by team",
                   "ga":"goal scored against team",
                   "opponent":"team's opponent",
                   "xg":"total goals expected",
                   "xga":"expected goals against",
                   "poss": "teams's possession",
                   "captain":"team's captain",
                   "formation":"team's formation",
                   "refree":"officiating refree",
                   "sh":"total shots",
                   "sot":"total short on target",
                   "fk":"shots from freekicks",
                    "pk":"penalty kicks made",
                    "pkatt":"peanlty kicks attempted",
                    "season":"current season",
                    "team":"team name"                   
                   }

data_dict_df = pd.DataFrame(data_dict.items(), columns=["columns","meaning"])
data_dict_df
# Out:
#       columns                   meaning
# 0        date          local match date
# 1        time   local time for kick-off
# 2         day              day of match
# 3       venue               match venue
# 4      result              match result
# 5          gf        goal score by team
# 6          ga  goal scored against team
# 7    opponent           team's opponent
# 8          xg      total goals expected
# 9         xga    expected goals against
# 10       poss        teams's possession
# 11    captain            team's captain
# 12  formation          team's formation
# 13     refree        officiating refree
# 14         sh               total shots
# 15        sot     total short on target
# 16         fk      shots from freekicks
# 17         pk        penalty kicks made
# 18      pkatt   peanlty kicks attempted
# 19     season            current season
# 20       team                 team name

# %% [markdown]
# Columns to work with:
# - day
# - venue
# - poss
# - sh
# - sot
# - fk
# - opponent
# - captain
# - formation

# %%
matches['result'].value_counts(dropna=False)
# Out:
# result
# W    1721
# L    1721
# D     984
# Name: count, dtype: int64

# %%
# matches['result'] =  matches['result'].astype('category').cat.codes
# matches['result'].value_counts()

# %%
# plots a box plot
@beartype
def plot_boxplot(df:pd.DataFrame, 
                 col: str, 
                 target:str) -> None:
    """
    Returns a box plot by taking in three arguements:
        df: The dataframe 
        col: The column of interest
        target: The target column.
    """
    plt.figure(figsize=(8, 5))
    feature = df[col]
    target = df[target]
    sns.boxplot(data=df, y=feature, x=target)
    plt.title(col)    
    plt.show()
    
# plots a distribution plot
def plot_displot(df:pd.DataFrame, 
                 col: str, 
                 extra_col: str = None, 
                 hue: str = None) -> None:
    """
    Returns a distribution plot by taking in two complusory keywords
    and two optional arguements:
        df: The dataframe 
        col: The column of interest
        extra_col:  Variables that define subsets to plot on different facets
        hue: This parameter takes a column name for colour encoding.
    """
    feature = df[col]
    ax1 = sns.displot(data=df, x=feature, hue=hue,col=extra_col,height=5, aspect=1.5,kde=True)
    ax1.fig.subplots_adjust(top=.8)
    ax1.fig.suptitle('Distribution of ' + col)



# plots a countplot
def plot_countplot(data1: pd.DataFrame, 
                   data2: pd.Series, 
                   col: str, 
                   title: str, 
                   hue: str = None) -> None:
    
    data1 = data1
    data2 = data2
    col = col
    if len(data2.index[0]) > 5:
        if hue is None:
            fig = plt.figure(figsize=(12,9))
            ax = sns.countplot(y=data1[col],
                            order=data2.index,
                            lw=1,
                            palette='cividis',
                            edgecolor='k'
                        )
        else:
            fig = plt.figure(figsize=(12,9))
            ax = sns.countplot(y=data1[col],
                            hue=hue,
                            order=data2.index,
                            lw=1,
                            palette='cividis',
                            edgecolor='k'
                        )
    else:
        if hue is None:
            fig = plt.figure(figsize=(12,9))
            ax = sns.countplot(x=data1[col],
                            order=data2.index,
                            lw=1,
                            palette='cividis',
                            edgecolor='k'
                        )
        else:
            fig = plt.figure(figsize=(12,9))
            ax = sns.countplot(x=data1[col],
                            hue=hue,
                            order=data2.index,
                            lw=1,
                            palette='cividis',
                            edgecolor='k'
                        )

        
    plt.title(title,fontsize=12,weight='bold')

# %% [markdown]
# ### Days

# %%
count_days = matches['day'].value_counts()/2
count_days
# Out:
# day
# Sat    1036.0
# Sun     583.0
# Wed     194.0
# Mon     127.0
# Tue     126.0
# Thu      79.0
# Fri      68.0
# Name: count, dtype: float64

# %%
count_days.sort_values(ascending=True).plot(kind="barh", title="Number of Games Played on each days and the Outcome between 2018 and 2024");

# %% [markdown]
# ### Captains

# %%
captain_count = matches['captain'].value_counts()/2
len(captain_count.index[0])
# Out:
# 10

# %%
captain_count[:20].sort_values(ascending=True).plot(kind='barh',title= "Players with most games played as Captain between 2019 and 2024", fontsize=10);

# %%
print(len(matches[matches['captain'].str.contains('Bruno Fernandes')]))
print(len(matches[matches['captain'].str.contains('Harry Maguire')]))
# Out:
# 70
# 95

# %%
print(f"Bruno Fernandes's Caps: {matches[matches['captain'].str.contains('Bruno Fernandes')]['season'].unique()}")
print(f"Harry Maguire's Caps: {matches[matches['captain'].str.contains('Harry Maguire')]['season'].unique()}")
# Out:
# Bruno Fernandes's Caps: [2024 2023 2022 2021]
# Harry Maguire's Caps: [2023 2022 2021 2020]

# %% [markdown]
# I'm a Manchester united fan, it's time I compare Bruno's and Maguire's Match results as captains

# %%
bruno_maguire_caps = matches[(matches['captain'].str.contains('Bruno Fernandes')) | (matches['captain'].str.contains('Harry Maguire'))]

# %%
bruno_maguire_caps.groupby('captain')['result'].value_counts()
# Out:
# captain          result
# Bruno Fernandes  W         34
#                  L         21
#                  D         15
# Harry Maguire    W         53
#                  D         23
#                  L         19
# Name: count, dtype: int64

# %%
plot_countplot(bruno_maguire_caps, bruno_maguire_caps['captain'].value_counts(), "captain", "Top 20 captains and the Outcome of Games they Played between 2018 and 2024", matches['result'])

# %% [markdown]
# ### Total Shots

# %%
plot_boxplot(matches, 'sh', 'result')

# %% [markdown]
# ### Shots on target

# %%
plot_boxplot(matches, 'sot', 'result')

# %% [markdown]
# let's check all columns if they need cleaning before contiuing the EDA

# %%
matches.dtypes
# Out:
# date          object
# time          object
# day           object
# venue         object
# result        object
# gf           float64
# ga           float64
# opponent      object
# xg           float64
# xga          float64
# poss         float64
# captain       object
# formation     object
# referee       object
# sh           float64
# sot          float64
# fk           float64
# pk             int64
# pkatt          int64
# season         int64
# team          object
# dtype: object

# %%
# Convert 'date' column to datetime
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches['time']
# Out:
# 0       12:30
# 1       20:00
# 2       15:00
# 3       16:30
# 4       16:30
#         ...
# 4421    12:30
# 4422    15:00
# 4423    20:00
# 4424    14:00
# 4425    15:00
# Name: time, Length: 4426, dtype: object

# %%
# Convert 'time' column to datetime
matches['time'] = pd.to_datetime(matches['time'], format='%H:%M').dt.time

# %%
matches['time']
# Out:
# 0       12:30:00
# 1       20:00:00
# 2       15:00:00
# 3       16:30:00
# 4       16:30:00
#           ...
# 4421    12:30:00
# 4422    15:00:00
# 4423    20:00:00
# 4424    14:00:00
# 4425    15:00:00
# Name: time, Length: 4426, dtype: object

# %%
matches['day'].unique()
# Out:
# array(['Sat', 'Mon', 'Sun', 'Tue', 'Thu', 'Wed', 'Fri'], dtype=object)

# %%
matches['venue'].unique()
# Out:
# array(['Home', 'Away'], dtype=object)

# %%
print(matches['gf'].unique())
matches['gf'] = matches['gf'].astype(int)
# Out:
# [2. 1. 3. 4. 5. 0. 6. 8. 9. 7.]

# %%
print(matches['ga'].unique())
matches['ga'] = matches['ga'].astype(int)
# Out:
# [1. 0. 2. 3. 4. 5. 6. 8. 7. 9.]

# %% [markdown]
# Renaming team names to match the team column

# %%
[i for i in sorted(matches['opponent'].unique()) if i not in sorted(matches['team'].unique())]
# Out:
# ['Brighton',
#  'Huddersfield',
#  'Manchester Utd',
#  'Newcastle Utd',
#  "Nott'ham Forest",
#  'Sheffield Utd',
#  'Tottenham',
#  'West Brom',
#  'West Ham',
#  'Wolves']

# %%
[i for i in sorted(matches['team'].unique()) if i not in sorted(matches['opponent'].unique())]
# Out:
# ['Brighton and Hove Albion',
#  'Huddersfield Town',
#  'Manchester United',
#  'Newcastle United',
#  'Nottingham Forest',
#  'Sheffield United',
#  'Tottenham Hotspur',
#  'West Bromwich Albion',
#  'West Ham United',
#  'Wolverhampton Wanderers']

# %%
matches['opponent'].replace(['Brighton','Manchester Utd', 'Huddersfield','Newcastle Utd',"Nott'ham Forest",'Sheffield Utd','Tottenham','West Brom','West Ham','Wolves'],
                            ['Brighton and Hove Albion','Manchester United', 'Huddersfield Town', 'Newcastle United','Nottingham Forest','Sheffield United','Tottenham Hotspur',
                             'West Bromwich Albion','West Ham United','Wolverhampton Wanderers'], inplace=True)

# %%
matches['opponent'].unique()
# Out:
# array(['Nottingham Forest', 'Crystal Palace', 'Fulham',
#        'Manchester United', 'Everton', 'Tottenham Hotspur', 'Bournemouth',
#        'Manchester City', 'Chelsea', 'Sheffield United',
#        'Newcastle United', 'Burnley', 'Brentford',
#        'Wolverhampton Wanderers', 'Luton Town', 'Aston Villa',
#        'Brighton and Hove Albion', 'Liverpool', 'West Ham United',
#        'Arsenal', 'Southampton', 'Leicester City', 'Leeds United',
#        'Norwich City', 'Watford', 'West Bromwich Albion',
#        'Huddersfield Town', 'Cardiff City'], dtype=object)

# %%
matches['xg'].unique()
# Out:
# array([0.8, 2. , 3.2, 2.3, 1. , 1.8, 3.4, 0.4, 2.8, 0.6, 1.6, 2.2, 1.4,
#        0.7, 2.7, 3.3, 1.2, 3.5, 3.6, 1.3, 3. , 0.9, 2.5, 2.6, 1.7, 2.1,
#        7. , 1.5, 2.9, 1.9, 0.5, 4. , 2.4, 1.1, 3.8, 4.1, 0.2, 0.3, 3.9,
#        3.1, 4.2, 3.7, 0.1, 0. , 4.3, 4.4, 5.2, 4.6, 5.9, 4.7, 4.8, 4.5])

# %%
matches['xga'].unique()
# Out:
# array([1.2, 1. , 0.6, 0.9, 0.3, 1.4, 0.5, 1.3, 0. , 1.1, 0.7, 0.4, 0.2,
#        2. , 2.2, 2.3, 0.1, 0.8, 1.6, 1.7, 3.5, 2.9, 1.8, 2.7, 2.1, 4.1,
#        2.6, 3.2, 1.5, 3.3, 2.5, 3.4, 4. , 2.4, 3. , 3.6, 1.9, 2.8, 3.8,
#        7. , 3.1, 3.7, 4.2, 3.9, 5.2, 4.4, 4.3, 5.9, 4.6, 4.7, 4.8, 4.5])

# %%
print(matches['poss'].unique())
matches['poss'] = matches['poss'].astype(int)
# Out:
# [78. 53. 71. 55. 74. 47. 57. 49. 56. 67. 58. 63. 66. 61. 48. 73. 60. 43.
#  70. 64. 80. 28. 46. 35. 41. 65. 36. 54. 77. 72. 75. 76. 68. 52. 50. 62.
#  69. 82. 59. 79. 51. 40. 45. 37. 39. 38. 32. 33. 44. 42. 27. 25. 22. 26.
#  30. 31. 34. 29. 23. 24. 21. 20. 18. 81. 19.]

# %%
matches[~(matches['captain'].str.contains('^[a-zA-Z0-9]'))]['captain'].unique()
# Out:
# array(['İlkay Gündoğan', 'Étienne Capoue'], dtype=object)

# %%
matches['formation'].unique()
# Out:
# array(['4-3-3', '4-2-3-1', '3-2-4-1', '3-4-3', '4-1-4-1', '4-4-2',
#        '4-2-2-2', '4-4-1-1', '3-5-2', '5-3-2', '4-1-2-1-2◆', '4-2-4-0',
#        '4-3-2-1', '4-5-1', '4-3-1-2', '5-4-1', '3-4-1-2', '3-5-1-1',
#        '3-4-3◆', '3-3-3-1', '3-1-4-2', '4-1-3-2'], dtype=object)

# %%
matches[matches['formation'].str.contains('4-1-2-1-2◆')]
# Out:
#            date      time  day venue result  gf  ga                  opponent  \
# 160  2023-09-16  15:00:00  Sat  Home      L   1   3  Brighton and Hove Albion
# 298  2023-12-28  19:30:00  Thu  Home      W   4   2         Tottenham Hotspur
# 789  2022-10-29  19:45:00  Sat  Home      L   1   2              Leeds United
# 790  2022-11-06  16:30:00  Sun  Away      W   2   1         Tottenham Hotspur
# 795  2023-01-14  15:00:00  Sat  Away      L   0   3  Brighton and Hove Albion
# 855  2022-08-13  12:30:00  Sat  Home      W   2   1                   Everton
# 1503 2021-09-11  12:30:00  Sat  Away      L   0   3            Crystal Palace
# 1706 2021-12-26  20:00:00  Sun  Home      W   2   0                 Brentford
# 1709 2022-01-14  20:00:00  Fri  Home      D   1   1            Crystal Palace
# 1711 2022-01-23  14:00:00  Sun  Away      D   1   1            Leicester City
# 1713 2022-02-15  20:15:00  Tue  Away      L   0   2         Manchester United
# 1716 2022-03-05  15:00:00  Sat  Away      L   1   2          Newcastle United
# 1904 2022-02-26  15:00:00  Sat  Away      W   2   0  Brighton and Hove Albion
# 1907 2022-03-13  14:00:00  Sun  Away      L   1   2           West Ham United
# 1913 2022-05-07  15:00:00  Sat  Away      W   3   1                   Burnley
# 2137 2022-04-02  15:00:00  Sat  Away      D   0   0  Brighton and Hove Albion
# 2189 2020-11-01  16:30:00  Sun  Home      L   0   1                   Arsenal
# 2515 2021-03-13  17:30:00  Sat  Home      L   1   2                   Burnley
# 2733 2021-01-13  18:00:00  Wed  Away      L   0   1           Manchester City
# 3009 2020-03-01  14:00:00  Sun  Away      D   1   1                   Everton
# 3073 2019-12-08  14:00:00  Sun  Away      W   4   1               Aston Villa
# 3074 2019-12-14  15:00:00  Sat  Home      D   1   1              Norwich City
# 3101 2019-09-21  12:30:00  Sat  Away      L   1   2            Leicester City
# 3176 2019-09-15  16:30:00  Sun  Away      D   2   2                   Watford
# 3452 2019-12-05  20:15:00  Thu  Away      W   2   1                   Arsenal
# 3458 2020-01-01  12:30:00  Wed  Home      D   1   1                   Chelsea
# 3545 2020-06-27  12:30:00  Sat  Home      L   0   1   Wolverhampton Wanderers
# 3592 2019-08-24  15:00:00  Sat  Home      L   1   3           West Ham United
# 3782 2018-08-27  20:00:00  Mon  Away      W   3   0         Manchester United
# 3784 2018-09-15  12:30:00  Sat  Home      L   1   2                 Liverpool
# 3792 2018-11-24  17:30:00  Sat  Home      W   3   1                   Chelsea
# 3793 2018-12-02  14:05:00  Sun  Away      L   2   4                   Arsenal
# 3797 2018-12-23  16:00:00  Sun  Away      W   6   2                   Everton
# 3799 2018-12-29  15:00:00  Sat  Home      L   1   3   Wolverhampton Wanderers
# 3800 2019-01-01  17:30:00  Tue  Away      W   3   0              Cardiff City
# 3801 2019-01-13  16:30:00  Sun  Home      L   0   1         Manchester United
# 3805 2019-02-10  13:30:00  Sun  Home      W   3   1            Leicester City
# 3809 2019-03-09  15:00:00  Sat  Away      L   1   2               Southampton
# 3815 2019-04-27  12:30:00  Sat  Home      L   0   1           West Ham United
# 3836 2018-12-26  17:15:00  Wed  Away      D   1   1  Brighton and Hove Albion
# 3840 2019-01-19  17:30:00  Sat  Home      W   2   0                   Chelsea
# 3877 2019-01-13  16:30:00  Sun  Away      W   1   0         Tottenham Hotspur
# 4340 2019-03-02  15:00:00  Sat  Away      L   0   2   Wolverhampton Wanderers
# 4363 2018-12-02  12:00:00  Sun  Away      L   0   2                   Chelsea
# 4413 2019-02-09  15:00:00  Sat  Home      L   1   2                   Arsenal
# 4414 2019-02-23  15:00:00  Sat  Away      L   0   2          Newcastle United
# 4415 2019-02-26  19:45:00  Tue  Home      W   1   0   Wolverhampton Wanderers
# 4416 2019-03-02  15:00:00  Sat  Away      L   0   1  Brighton and Hove Albion
#
#        xg  xga  ...                captain   formation          referee    sh  \
# 160   1.0  1.7  ...        Bruno Fernandes  4-1-2-1-2◆   Jarred Gillett  14.0
# 298   3.2  2.3  ...             Lewis Dunk  4-1-2-1-2◆   Jarred Gillett  13.0
# 789   1.7  1.8  ...        Virgil van Dijk  4-1-2-1-2◆   Michael Oliver  22.0
# 790   1.2  1.2  ...        Virgil van Dijk  4-1-2-1-2◆      Andy Madley  13.0
# 795   1.0  1.9  ...       Jordan Henderson  4-1-2-1-2◆   Darren England   6.0
# 855   2.3  1.6  ...            John McGinn  4-1-2-1-2◆   Michael Oliver  12.0
# 1503  0.1  2.1  ...            Hugo Lloris  4-1-2-1-2◆    Jonathan Moss   2.0
# 1706  0.8  0.7  ...           Adam Lallana  4-1-2-1-2◆   Darren England  15.0
# 1709  2.0  0.2  ...           Adam Lallana  4-1-2-1-2◆     Robert Jones  18.0
# 1711  1.1  1.4  ...           Adam Webster  4-1-2-1-2◆  Martin Atkinson  14.0
# 1713  0.7  1.7  ...             Lewis Dunk  4-1-2-1-2◆     Peter Bankes  10.0
# 1716  1.5  1.7  ...             Lewis Dunk  4-1-2-1-2◆  Martin Atkinson  15.0
# 1904  1.0  0.7  ...           Tyrone Mings  4-1-2-1-2◆      John Brooks   9.0
# 1907  1.1  1.2  ...           Tyrone Mings  4-1-2-1-2◆   Jarred Gillett  13.0
# 1913  2.1  1.9  ...           Tyrone Mings  4-1-2-1-2◆      David Coote  12.0
# 2137  0.4  2.8  ...           Grant Hanley  4-1-2-1-2◆     Simon Hooper   6.0
# 2189  0.4  1.0  ...          Harry Maguire  4-1-2-1-2◆        Mike Dean   8.0
# 2515  1.5  0.8  ...            Lucas Digne  4-1-2-1-2◆    Jonathan Moss  14.0
# 2733  0.2  2.0  ...             Lewis Dunk  4-1-2-1-2◆   Darren England   5.0
# 3009  1.1  2.1  ...          Harry Maguire  4-1-2-1-2◆   Chris Kavanagh  14.0
# 3073  4.6  1.2  ...      Kasper Schmeichel  4-1-2-1-2◆   Michael Oliver  23.0
# 3074  1.1  1.1  ...      Kasper Schmeichel  4-1-2-1-2◆      Andy Madley  18.0
# 3101  1.1  1.3  ...             Harry Kane  4-1-2-1-2◆     Paul Tierney  11.0
# 3176  0.8  2.7  ...           Granit Xhaka  4-1-2-1-2◆   Anthony Taylor   7.0
# 3452  1.7  0.9  ...             Lewis Dunk  4-1-2-1-2◆     Graham Scott  20.0
# 3458  1.3  1.3  ...             Lewis Dunk  4-1-2-1-2◆   Stuart Attwell  16.0
# 3545  0.6  0.7  ...          Jack Grealish  4-1-2-1-2◆     Craig Pawson  11.0
# 3592  2.3  3.5  ...         Étienne Capoue  4-1-2-1-2◆   Chris Kavanagh  23.0
# 3782  1.2  1.5  ...            Hugo Lloris  4-1-2-1-2◆     Craig Pawson   9.0
# 3784  1.0  2.6  ...             Harry Kane  4-1-2-1-2◆   Michael Oliver  11.0
# 3792  3.1  1.0  ...            Hugo Lloris  4-1-2-1-2◆  Martin Atkinson  18.0
# 3793  1.2  2.7  ...            Hugo Lloris  4-1-2-1-2◆        Mike Dean  10.0
# 3797  2.0  0.9  ...            Hugo Lloris  4-1-2-1-2◆     Paul Tierney  17.0
# 3799  0.3  0.9  ...            Hugo Lloris  4-1-2-1-2◆   Stuart Attwell  10.0
# 3800  1.1  0.9  ...            Hugo Lloris  4-1-2-1-2◆     Kevin Friend  13.0
# 3801  1.8  0.8  ...            Hugo Lloris  4-1-2-1-2◆        Mike Dean  21.0
# 3805  1.1  3.3  ...            Hugo Lloris  4-1-2-1-2◆   Michael Oliver  12.0
# 3809  1.3  2.1  ...            Hugo Lloris  4-1-2-1-2◆     Kevin Friend  16.0
# 3815  1.6  1.1  ...            Hugo Lloris  4-1-2-1-2◆   Anthony Taylor  14.0
# 3836  0.8  1.1  ...      Laurent Koscielny  4-1-2-1-2◆   Anthony Taylor   7.0
# 3840  1.5  0.9  ...      Laurent Koscielny  4-1-2-1-2◆   Anthony Taylor  13.0
# 3877  0.8  1.8  ...           Ashley Young  4-1-2-1-2◆        Mike Dean  13.0
# 4340  0.6  2.8  ...          Sean Morrison  4-1-2-1-2◆   Andre Marriner  12.0
# 4363  0.4  2.1  ...            Tom Cairney  4-1-2-1-2◆     Craig Pawson   9.0
# 4413  1.6  1.4  ...            Tommy Smith  4-1-2-1-2◆    Jonathan Moss  16.0
# 4414  0.2  2.8  ...            Tommy Smith  4-1-2-1-2◆     Kevin Friend   3.0
# 4415  1.6  0.6  ...  Christopher Schindler  4-1-2-1-2◆      David Coote  15.0
# 4416  0.2  1.2  ...  Christopher Schindler  4-1-2-1-2◆        Mike Dean   6.0
#
#        sot   fk  pk  pkatt  season                      team
# 160    4.0  1.0   0      0    2024         Manchester United
# 298    7.0  0.0   2      2    2024  Brighton and Hove Albion
# 789   10.0  0.0   0      0    2023                 Liverpool
# 790    6.0  0.0   0      0    2023                 Liverpool
# 795    2.0  0.0   0      0    2023                 Liverpool
# 855    3.0  0.0   0      0    2023               Aston Villa
# 1503   1.0  0.0   0      0    2022         Tottenham Hotspur
# 1706   5.0  3.0   0      0    2022  Brighton and Hove Albion
# 1709   3.0  0.0   0      1    2022  Brighton and Hove Albion
# 1711   4.0  0.0   0      0    2022  Brighton and Hove Albion
# 1713   3.0  0.0   0      0    2022  Brighton and Hove Albion
# 1716   4.0  0.0   0      0    2022  Brighton and Hove Albion
# 1904   4.0  1.0   0      0    2022               Aston Villa
# 1907   7.0  1.0   0      0    2022               Aston Villa
# 1913   7.0  1.0   0      0    2022               Aston Villa
# 2137   0.0  0.0   0      0    2022              Norwich City
# 2189   2.0  0.0   0      0    2021         Manchester United
# 2515   4.0  0.0   0      0    2021                   Everton
# 2733   1.0  0.0   0      0    2021  Brighton and Hove Albion
# 3009   5.0  0.0   0      0    2020         Manchester United
# 3073   8.0  0.0   0      0    2020            Leicester City
# 3074   5.0  0.0   0      0    2020            Leicester City
# 3101   4.0  0.0   0      0    2020         Tottenham Hotspur
# 3176   4.0  0.0   0      0    2020                   Arsenal
# 3452   9.0  1.0   0      0    2020  Brighton and Hove Albion
# 3458   5.0  1.0   0      0    2020  Brighton and Hove Albion
# 3545   1.0  0.0   0      0    2020               Aston Villa
# 3592   3.0  0.0   0      0    2020                   Watford
# 3782   5.0  0.0   0      0    2019         Tottenham Hotspur
# 3784   3.0  2.0   0      0    2019         Tottenham Hotspur
# 3792   9.0  0.0   0      0    2019         Tottenham Hotspur
# 3793   5.0  1.0   1      1    2019         Tottenham Hotspur
# 3797   8.0  3.0   0      0    2019         Tottenham Hotspur
# 3799   3.0  1.0   0      0    2019         Tottenham Hotspur
# 3800   4.0  0.0   0      0    2019         Tottenham Hotspur
# 3801  11.0  2.0   0      0    2019         Tottenham Hotspur
# 3805   5.0  0.0   0      0    2019         Tottenham Hotspur
# 3809   5.0  1.0   0      0    2019         Tottenham Hotspur
# 3815   4.0  1.0   0      0    2019         Tottenham Hotspur
# 3836   4.0  0.0   0      0    2019                   Arsenal
# 3840   5.0  0.0   0      0    2019                   Arsenal
# 3877   8.0  0.0   0      0    2019         Manchester United
# 4340   3.0  0.0   0      0    2019              Cardiff City
# 4363   4.0  0.0   0      0    2019                    Fulham
# 4413   6.0  0.0   0      0    2019         Huddersfield Town
# 4414   0.0  0.0   0      0    2019         Huddersfield Town
# 4415   3.0  0.0   0      0    2019         Huddersfield Town
# 4416   4.0  0.0   0      0    2019         Huddersfield Town
#
# [48 rows x 21 columns]

# %%
matches['formation'].replace(["4-1-2-1-2◆","3-4-3◆","4-2-4-0"], ["4-1-2-1-2", "3-4-3", "4-2-4"], inplace=True)

# %%
matches['formation'].unique()
# Out:
# array(['4-3-3', '4-2-3-1', '3-2-4-1', '3-4-3', '4-1-4-1', '4-4-2',
#        '4-2-2-2', '4-4-1-1', '3-5-2', '5-3-2', '4-1-2-1-2', '4-2-4',
#        '4-3-2-1', '4-5-1', '4-3-1-2', '5-4-1', '3-4-1-2', '3-5-1-1',
#        '3-3-3-1', '3-1-4-2', '4-1-3-2'], dtype=object)

# %%
matches.groupby('formation')['result'].value_counts().sort_values(ascending=False)[:20]
# Out:
# formation  result
# 4-2-3-1    W         503
# 4-3-3      W         486
# 4-2-3-1    L         439
# 4-3-3      L         264
# 4-2-3-1    D         246
# 4-4-2      L         239
# 4-3-3      D         203
# 3-4-3      W         191
#            L         182
# 4-4-2      W         173
#            D         132
# 3-5-2      L         121
# 3-4-3      D         112
# 4-1-4-1    L         102
# 4-4-1-1    L          91
# 4-1-4-1    W          71
# 3-5-2      W          67
# 5-4-1      L          58
# 3-5-2      D          57
# 4-1-4-1    D          56
# Name: count, dtype: int64

# %%
matches['formation'].unique()
# Out:
# array(['4-3-3', '4-2-3-1', '3-2-4-1', '3-4-3', '4-1-4-1', '4-4-2',
#        '4-2-2-2', '4-4-1-1', '3-5-2', '5-3-2', '4-1-2-1-2', '4-2-4',
#        '4-3-2-1', '4-5-1', '4-3-1-2', '5-4-1', '3-4-1-2', '3-5-1-1',
#        '3-3-3-1', '3-1-4-2', '4-1-3-2'], dtype=object)

# %%
plot_countplot(matches, matches['formation'].value_counts(), 'formation', 'Formations and Match Results Count from 2019 t0 2024 Seasons', matches['result'])

# %%
matches['referee'].unique()
# Out:
# array(['Michael Oliver', 'David Coote', 'Paul Tierney', 'Anthony Taylor',
#        'Simon Hooper', 'Robert Jones', 'Michael Salisbury',
#        'Chris Kavanagh', 'Tim Robinson', 'Stuart Attwell', 'Peter Bankes',
#        'Samuel Barrott', 'Jarred Gillett', 'Joshua Smith', 'Craig Pawson',
#        'John Brooks', 'Thomas Bramall', 'Andy Madley', 'Darren England',
#        'Lewis Smith', 'Tony Harrington', 'Graham Scott', 'Samuel Allison',
#        'Darren Bond', 'Robert Madley', 'Rebecca Welch', 'Sunny Singh',
#        'Andre Marriner', 'Martin Atkinson', 'Jonathan Moss',
#        'Kevin Friend', 'Mike Dean', 'Lee Mason', 'Oliver Langford',
#        'Lee Probert', 'Roger East'], dtype=object)

# %%
refree_count = matches['referee'].value_counts()/2

# %%
refree_count.sort_values(ascending=True).plot(kind='barh',fontsize=10, title="Officiating Referees with Number of Games Between 2019 and 2024");

# %%
print(matches['sh'].unique())
matches['sh'] = matches['sh'].astype(int)
# Out:
# [15. 13. 18. 17. 12. 14. 16. 19. 23. 26. 30. 21. 24. 22.  6. 25.  9.  8.
#  34. 32. 27. 10. 29.  7.  4. 20.  2. 31. 28. 11.  3.  5.  1.  0. 36.]

# %%
print(matches['sot'].unique())
matches['sot'] = matches['sot'].astype(int)
# Out:
# [ 7.  2.  9.  5.  4.  6.  3.  1.  8. 11. 10. 12. 13.  0. 15. 14.]

# %%
print(matches['fk'].unique())
matches['fk'] = matches['fk'].astype(int)
# Out:
# [0. 1. 2. 3. 4.]

# %%
print(matches['pk'].unique())
# Out:
# [0 1 2 3]

# %%
print(matches['pkatt'].unique())
# Out:
# [0 1 2 3]

# %%
# check if each value in both columns are equal at each index
{True for i, j in zip(matches['pk'], matches['pkatt']) if i == j}
# Out:
# {True}

# %%
# drop pk column
matches.drop(columns='pk', inplace=True)
matches.shape
# Out:
# (4426, 20)

# %%
matches['season'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019])

# %% [markdown]
# Create a total goals column and a year column

# %%
matches['total_goals'] = matches['ga'] + matches['gf']

# %%
matches['year'] = matches['date'].apply(lambda x: x.strftime('%Y'))

# %%
x = matches.query("year=='2023'")
x.query("opponent=='Nottingham Forest'").iloc[0].to_frame().T
# Out:
#                   date      time  day venue result gf ga           opponent  \
# 0  2023-08-12 00:00:00  12:30:00  Sat  Home      W  2  1  Nottingham Forest
#
#     xg  xga  ... formation         referee  sh sot fk pkatt season     team  \
# 0  0.8  1.2  ...     4-3-3  Michael Oliver  15   7  0     0   2024  Arsenal
#
#   total_goals  year
# 0           3  2023
#
# [1 rows x 22 columns]

# %%
year_count = (matches['year'].value_counts() / 2).to_frame().reset_index()
year_count
# Out:
#    year  count
# 0  2023  412.0
# 1  2021  408.0
# 2  2019  379.0
# 3  2022  361.0
# 4  2020  336.0
# 5  2018  200.0
# 6  2024  117.0

# %%
sns.barplot(x='year', y='count', data=year_count)
plt.title('Number of Matches Played in Each Year', weight='bold');

# %%
goals_per_year = (matches.groupby('year')['total_goals'].sum()/ 2).to_frame().reset_index()
goals_per_year
# Out:
#    year  total_goals
# 0  2018        569.0
# 1  2019       1062.0
# 2  2020        909.0
# 3  2021       1108.0
# 4  2022       1025.0
# 5  2023       1222.0
# 6  2024        403.0

# %%
sns.barplot(x='year', y='total_goals', data=goals_per_year)
# Out:
# <Axes: xlabel='year', ylabel='total_goals'>

# %% [markdown]
# # Identifying Outliers and Handling Outliers
#
# <font size="4">I will be identifying outliers by visualizing the data points using `seaborn.boxplot()`.

# %%
matches.head(2)
# Out:
#         date      time  day venue result  gf  ga           opponent   xg  xga  \
# 0 2023-08-12  12:30:00  Sat  Home      W   2   1  Nottingham Forest  0.8  1.2
# 1 2023-08-21  20:00:00  Mon  Away      W   1   0     Crystal Palace  2.0  1.0
#
#    ...  formation         referee  sh sot  fk  pkatt  season     team  \
# 0  ...      4-3-3  Michael Oliver  15   7   0      0    2024  Arsenal
# 1  ...      4-3-3     David Coote  13   2   0      1    2024  Arsenal
#
#    total_goals  year
# 0            3  2023
# 1            1  2023
#
# [2 rows x 22 columns]

# %%
matches['xg'].describe()
# Out:
# count    4426.000000
# mean        1.379530
# std         0.814899
# min         0.000000
# 25%         0.800000
# 50%         1.200000
# 75%         1.800000
# max         7.000000
# Name: xg, dtype: float64

# %%
matches.query("xg>4.5")['xg'].value_counts()
# Out:
# xg
# 4.6    3
# 5.9    2
# 5.2    1
# 7.0    1
# 4.7    1
# 4.8    1
# Name: count, dtype: int64

# %%
plot_boxplot(matches, 'xg', 'result')

# %%
matches.loc[matches['xg']>4.5, 'xg'] =  4.5

# %%
plot_boxplot(matches, 'xg', 'result')

# %%
matches.query("xg>4.5")['xg'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
matches.query("xga>4.5")['xga'].value_counts()
# Out:
# xga
# 4.6    3
# 5.9    2
# 5.2    1
# 7.0    1
# 4.7    1
# 4.8    1
# Name: count, dtype: int64

# %%
matches.loc[matches['xga']>4.5, 'xga'] =  4.5

# %%
plot_boxplot(matches, 'xga', 'result')

# %%
plot_boxplot(matches, 'poss', 'result')

# %%
plot_boxplot(matches,'sh','result')

# %%
matches['sh'].describe()
# Out:
# count    4426.000000
# mean       12.542702
# std         5.506656
# min         0.000000
# 25%         8.250000
# 50%        12.000000
# 75%        16.000000
# max        36.000000
# Name: sh, dtype: float64

# %%
matches.loc[matches['sh'] > 30, 'sh'] = 30

# %%
plot_boxplot(matches,'sh','result')

# %%
plot_boxplot(matches,'sot','result')

# %%
matches['sot'].describe()
# Out:
# count    4426.000000
# mean        4.188432
# std         2.440471
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        15.000000
# Name: sot, dtype: float64

# %%
matches['sot'].quantile(0.99)
# Out:
# 11.0

# %%
matches.loc[matches['sot']>matches['sot'].quantile(0.99), 'sot'] = matches['sot'].quantile(0.99)

# %%
plot_boxplot(matches, 'sot', 'result')

# %%
matches['fk'].describe()
# Out:
# count    4426.000000
# mean        0.443742
# std         0.660849
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         4.000000
# Name: fk, dtype: float64

# %%
plot_boxplot(matches,'fk','result')

# %%
matches['fk'].value_counts()
# Out:
# fk
# 0    2831
# 1    1271
# 2     285
# 3      33
# 4       6
# Name: count, dtype: int64

# %%
matches.loc[matches['fk']>matches['fk'].quantile(0.99),'fk'] = matches['fk'].quantile(0.99)

# %%
plot_boxplot(matches,'fk','result')

# %%
matches['pkatt'].describe()
# Out:
# count    4426.000000
# mean        0.138048
# std         0.369043
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: pkatt, dtype: float64

# %%
matches['pkatt'].value_counts()
# Out:
# pkatt
# 0    3852
# 1     538
# 2      35
# 3       1
# Name: count, dtype: int64

# %%
plot_boxplot(matches,'pkatt', 'result')

# %%
matches.loc[matches['pkatt']>1, 'pkatt'] = 1

# %%
plot_boxplot(matches, 'pkatt', 'result')

# %%
matches
# Out:
#            date      time  day venue result  gf  ga           opponent   xg  \
# 0    2023-08-12  12:30:00  Sat  Home      W   2   1  Nottingham Forest  0.8
# 1    2023-08-21  20:00:00  Mon  Away      W   1   0     Crystal Palace  2.0
# 2    2023-08-26  15:00:00  Sat  Home      D   2   2             Fulham  3.2
# 3    2023-09-03  16:30:00  Sun  Home      W   3   1  Manchester United  2.3
# 4    2023-09-17  16:30:00  Sun  Away      W   1   0            Everton  1.0
# ...         ...       ...  ...   ...    ...  ..  ..                ...  ...
# 4421 2019-04-13  12:30:00  Sat  Away      L   0   4  Tottenham Hotspur  0.8
# 4422 2019-04-20  15:00:00  Sat  Home      L   1   2            Watford  1.0
# 4423 2019-04-26  20:00:00  Fri  Away      L   0   5          Liverpool  0.2
# 4424 2019-05-05  14:00:00  Sun  Home      D   1   1  Manchester United  1.0
# 4425 2019-05-12  15:00:00  Sun  Away      D   1   1        Southampton  0.7
#
#       xga  ...  formation         referee  sh sot  fk  pkatt  season  \
# 0     1.2  ...      4-3-3  Michael Oliver  15   7   0      0    2024
# 1     1.0  ...      4-3-3     David Coote  13   2   0      1    2024
# 2     0.6  ...      4-3-3    Paul Tierney  18   9   0      1    2024
# 3     0.9  ...      4-3-3  Anthony Taylor  17   5   0      0    2024
# 4     0.3  ...      4-3-3    Simon Hooper  13   4   0      0    2024
# ...   ...  ...        ...             ...  ..  ..  ..    ...     ...
# 4421  2.5  ...      5-4-1       Lee Mason   7   1   1      0    2019
# 4422  0.9  ...    4-4-1-1      Roger East  13   3   1      0    2019
# 4423  3.1  ...    4-1-4-1    Kevin Friend   5   1   0      0    2019
# 4424  1.8  ...      4-3-3       Lee Mason   7   3   1      0    2019
# 4425  0.6  ...      4-3-3     Lee Probert  10   3   0      0    2019
#
#                    team  total_goals  year
# 0               Arsenal            3  2023
# 1               Arsenal            1  2023
# 2               Arsenal            4  2023
# 3               Arsenal            4  2023
# 4               Arsenal            1  2023
# ...                 ...          ...   ...
# 4421  Huddersfield Town            4  2019
# 4422  Huddersfield Town            3  2019
# 4423  Huddersfield Town            5  2019
# 4424  Huddersfield Town            2  2019
# 4425  Huddersfield Town            2  2019
#
# [4426 rows x 22 columns]

# %% [markdown]
# ## Feature Selection Features

# %%
matches['target'] = (matches['result']=='W').astype('int')

# %%
matches.drop(columns='result', inplace=True)

# %%
matches.drop(columns=['season', 'total_goals','year'], inplace=True)

# %%
categorical_feat = [col for col in matches.columns if matches[col].dtype=='O']
num_feat = [col for col in matches.columns if col not in categorical_feat][1:]

# %%
categorical_feat
# Out:
# ['time', 'day', 'venue', 'opponent', 'captain', 'formation', 'referee', 'team']

# %%
matches.columns
# Out:
# Index(['date', 'time', 'day', 'venue', 'gf', 'ga', 'opponent', 'xg', 'xga',
#        'poss', 'captain', 'formation', 'referee', 'sh', 'sot', 'fk', 'pkatt',
#        'team', 'target'],
#       dtype='object')

# %%
# feature correlation with  Target
matches[num_feat].corr()['target'].drop('target').sort_values(ascending=True).plot(kind='barh',color='steelblue');
plt.title('Correlation of numerical features with target'.upper(), weight='bold', fontsize=12)
# Out:
# Text(0.5, 1.0, 'CORRELATION OF NUMERICAL FEATURES WITH TARGET')

# %%
features = ['venue','opponent', 'formation', 'team','captain','xg','xga','poss','sh','sot','fk','pkatt']

# %%
matches['date'].max()
# Out:
# Timestamp('2024-04-07 00:00:00')

# %%
X = matches[features]
y = matches['target']

# %%
seed = 1234 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=seed)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3098, 12), (1328, 12), (3098,), (1328,))

# %%
for i in features:
    print(i)
    print(matches[i].nunique())
# Out:
# venue
# 2
# opponent
# 28
# formation
# 21
# team
# 28
# captain
# 203
# xg
# 46
# xga
# 46
# poss
# 65
# sh
# 31
# sot
# 12
# fk
# 3
# pkatt
# 2

# %%
import category_encoders
print(category_encoders.__version__)

import sklearn
sklearn.__version__
# Out:
# 2.6.3
# '1.2.2'

# %%
encoder = TargetEncoder(cols=['opponent','formation','team','captain']).fit(X_train, y_train) 
X_train = encoder.transform(X_train)
X_test = encoder.transform(X_test)

# %%
cols =  ['xg', 'xga', 'poss', 'sh', 'sot', 'fk', 'pkatt','opponent','formation','team','captain']

# %%
def preprocessor_pipe(num_features):
    numeric_features = num_features
    numeric_transformer = Pipeline(
        steps=[
            # its a good practice to do the polynomial/interaction feature generation before scaling.
            # ("poly_int", PolynomialFeatures(interaction_only=True, include_bias=False)),
            ("scaler", StandardScaler())
        ]
    ).set_output(transform='pandas')

    categorical_features = ['venue']
    categorical_transformer = Pipeline(
        steps=[
            ("ohe", OneHotEncoder(handle_unknown="infrequent_if_exist", sparse_output=False, drop='if_binary')),
        ]
    ).set_output(transform='pandas')

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, numeric_features),
            ("cat", categorical_transformer, categorical_features),
        ],
        remainder='passthrough',
        verbose_feature_names_out=False
    ).set_output(transform="pandas")

    return preprocessor

# %%
preprocessor = preprocessor_pipe(num_features=cols) 
Xtrainpreprocessed = preprocessor.fit_transform(X_train)
Xtestpreprocessed = preprocessor.transform(X_test)

# %%
seed = 1234
def model_selection(xtrain,xtest,ytrain,ytest):
    models = {
        'Logistic_regression':{
            'model':LogisticRegression(random_state=seed)
        },
        'random_forest':{
            'model':RandomForestClassifier(random_state=seed)
        },
        'gradient_boost':{
            'model':GradientBoostingClassifier(random_state=seed)
        },
        'histgradient_boost':{
            'model':HistGradientBoostingClassifier(random_state=seed)
        }
    }

    scores = []
    for model_name, config in models.items():
        start = time.time()
        config['model'].fit(xtrain, ytrain)
        y_pred = config['model'].predict(xtest) 
        train_score = config['model'].score(xtrain, ytrain)
        acc = accuracy_score(ytest, y_pred)
        precision_ = precision_score(ytest, y_pred)
        f1 = f1_score(ytest, y_pred)
        end = time.time()
        elasped_time = end - start
        scores.append({
            'model': model_name,
            'train_score':train_score,
            'accuracy_score':acc,
            'precision_score':precision_,
            'f1_score':f1,
            'time_taken':elasped_time})

    return pd.DataFrame(scores,columns=['model','train_score','accuracy_score','precision_score','f1_score','time_taken'])

# %%
all_features = model_selection(Xtrainpreprocessed, Xtestpreprocessed, y_train, y_test)

# %%
all_features
# Out:
#                  model  train_score  accuracy_score  precision_score  \
# 0  Logistic_regression     0.800516        0.798946         0.790698
# 1        random_forest     1.000000        0.766566         0.778846
# 2       gradient_boost     0.843447        0.774849         0.768212
# 3   histgradient_boost     0.950613        0.765060         0.746781
#
#    f1_score  time_taken
# 0  0.736946    0.022325
# 1  0.676409    0.406397
# 2  0.699497    0.326904
# 3  0.690476    0.350076

# %% [markdown]
# I'm really interested in our the XGboost model will perform on this dataset.
#
# However, I'm going to perform hyperparameter tunning using `hyperopt` and `MlFlow`.
#
# I'm not going to track the other models as this is not a key objective for this project.

# %% [markdown]
# ## Hyperparameter tunning on XGBoostClassifier

# %%
# Set tracking uri and set experiments
mlflow.set_tracking_uri("sqlite:////workspaces/MLOps/mlflow.db")
# mlflow.create_experiment('epl_match_winners', artifact_location="../mlruns")
mlflow.set_experiment("epl_match_winners")
# Out:
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/04/10 18:19:43 INFO mlflow.tracking.fluent: Experiment with name 'epl_match_winners' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/workspaces/MLOps/notebooks/mlruns/1', creation_time=1744309183880, experiment_id='1', last_update_time=1744309183880, lifecycle_stage='active', name='epl_match_winners', tags={}>

# %% [markdown]
# ### XGboost takes a specific data type

# %%
train = xgb.DMatrix(Xtrainpreprocessed, label=y_train)
valid = xgb.DMatrix(Xtestpreprocessed, label=y_test)

# %%
Xtestpreprocessed
# Out:
#             xg       xga      poss        sh       sot        fk     pkatt  \
# 2634 -1.202452  0.769815  0.614550 -0.102369 -0.900346  0.911276 -0.380609
# 2400  1.629741 -1.082476  1.001799 -0.102369  0.351197  0.911276 -0.380609
# 4130  0.521492 -0.712018  1.311599  2.626887  0.768378  0.911276 -0.380609
# 1086  0.152075 -1.205962  1.156699  0.807383 -0.483165  0.911276 -0.380609
# 85    1.506602  0.028898  1.543949  3.172738  0.351197  0.911276 -0.380609
# ...        ...       ...       ...       ...       ...       ...       ...
# 4330 -0.586758  0.893301 -0.934449 -0.648220 -0.065984 -0.685519 -0.380609
# 1637 -0.709896 -1.329449  1.079249 -0.648220 -0.900346 -0.685519 -0.380609
# 1775 -1.448729  1.016787 -2.251099 -1.194072 -1.317527 -0.685519 -0.380609
# 2950  1.752880  1.263759  1.001799  1.171284  1.602740  0.911276 -0.380609
# 2102 -1.079313  2.745592 -1.786399 -1.376022 -0.900346 -0.685519 -0.380609
#
#       opponent  formation      team   captain  venue_Home
# 2634  1.133894  -0.302282 -0.269046 -0.118749         1.0
# 2400  0.400838   0.435089  0.920972  1.362594         1.0
# 4130 -0.128604  -1.113133 -0.223966 -0.655853         1.0
# 1086  1.007790   1.211413 -0.269046 -0.763398         0.0
# 85   -0.997778  -0.727277  2.514696  1.078112         1.0
# ...        ...        ...       ...       ...         ...
# 4330  0.400838  -1.987289 -0.584313 -0.761080         0.0
# 1637  1.326257   0.435089  0.022804  0.158260         1.0
# 1775 -0.997778  -2.936773 -0.223966 -0.655853         1.0
# 2950  0.388038   1.211413  2.514696  1.982644         0.0
# 2102 -1.856257   1.211413 -1.075811 -1.198367         0.0
#
# [1328 rows x 12 columns]

# %% [markdown]
# ### Using `hpyeropt` for hyper paramter tuning. It uses bayesian method to find the best parameters
#
# [SOME DOCS](https://hyperopt.github.io/hyperopt/getting-started/search_spaces/)

# %%
def objective(params):

    # With MLflow autologging, hyperparameters and the trained model are automatically logged to MLflow.
    mlflow.xgboost.autolog(silent=True)

    with mlflow.start_run():
        mlflow.set_tag("Developer", "Dolapo Adebo")
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        auc = roc_auc_score(y_test, y_pred)
        mlflow.log_metric("auc",auc)
    
    # Set the loss to -1*auc_score so fmin maximizes the auc_score
    return {'loss': -auc, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'lambda': hp.loguniform('lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'seed': seed,
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]
# [0]	validation-auc:0.78600
# [1]	validation-auc:0.79302
# [2]	validation-auc:0.80521
# [3]	validation-auc:0.81042
# [4]	validation-auc:0.81543
# [5]	validation-auc:0.81861
# [6]	validation-auc:0.81970
# [7]	validation-auc:0.82231
# [8]	validation-auc:0.82675
# [9]	validation-auc:0.82891
# [10]	validation-auc:0.82932
# [11]	validation-auc:0.83009
# [12]	validation-auc:0.83192
# [13]	validation-auc:0.83365
# [14]	validation-auc:0.83454
# [15]	validation-auc:0.83551
# [16]	validation-auc:0.83605
# [17]	validation-auc:0.83603
# [18]	validation-auc:0.83717
# [19]	validation-auc:0.83797
# [20]	validation-auc:0.83871
# [21]	validation-auc:0.83859
# [22]	validation-auc:0.83937
# [23]	validation-auc:0.84106
# [24]	validation-auc:0.84162
# [25]	validation-auc:0.84173
# [26]	validation-auc:0.84229
# [27]	validation-auc:0.84319
# [28]	validation-auc:0.84441
# [29]	validation-auc:0.84463
# [30]	validation-auc:0.84502
# [31]	validation-auc:0.84508
# [32]	validation-auc:0.84539
# [33]	validation-auc:0.84611
# [34]	validation-auc:0.84653
# [35]	validation-auc:0.84741
# [36]	validation-auc:0.84822
# [37]	validation-auc:0.84799
# [38]	validation-auc:0.84871
# [39]	validation-auc:0.84878
# [40]	validation-auc:0.84927
# [41]	validation-auc:0.84922
# [42]	validation-auc:0.85014
# [43]	validation-auc:0.85032
# [44]	validation-auc:0.85036
# [45]	validation-auc:0.85086
# [46]	validation-auc:0.85123
# [47]	validation-auc:0.85165
# [48]	validation-auc:0.85144
# [49]	validation-auc:0.85137
# [50]	validation-auc:0.85183
# [51]	validation-auc:0.85241
# [52]	validation-auc:0.85283
# [53]	validation-auc:0.85294
# [54]	validation-auc:0.85296
# [55]	validation-auc:0.85280
# [56]	validation-auc:0.85281
# [57]	validation-auc:0.85314
# [58]	validation-auc:0.85342
# [59]	validation-auc:0.85378
# [60]	validation-auc:0.85371
# [61]	validation-auc:0.85412
# [62]	validation-auc:0.85411
# [63]	validation-auc:0.85436
# [64]	validation-auc:0.85451
# [65]	validation-auc:0.85478
# [66]	validation-auc:0.85460
# [67]	validation-auc:0.85433
# [68]	validation-auc:0.85458
# [69]	validation-auc:0.85438
# [70]	validation-auc:0.85447
# [71]	validation-auc:0.85460
# [72]	validation-auc:0.85448
# [73]	validation-auc:0.85463
# [74]	validation-auc:0.85462
# [75]	validation-auc:0.85468
# [76]	validation-auc:0.85476
# [77]	validation-auc:0.85479
# [78]	validation-auc:0.85469
# [79]	validation-auc:0.85485
# [80]	validation-auc:0.85476
# [81]	validation-auc:0.85482
# [82]	validation-auc:0.85472
# [83]	validation-auc:0.85449
# [84]	validation-auc:0.85411
# [85]	validation-auc:0.85411
# [86]	validation-auc:0.85420
# [87]	validation-auc:0.85408
# [88]	validation-auc:0.85411
# [89]	validation-auc:0.85397
# [90]	validation-auc:0.85394
# [91]	validation-auc:0.85361
# [92]	validation-auc:0.85317
# [93]	validation-auc:0.85326
# [94]	validation-auc:0.85348
# [95]	validation-auc:0.85358
# [96]	validation-auc:0.85368
# [97]	validation-auc:0.85371
# [98]	validation-auc:0.85372
# [99]	validation-auc:0.85362
# [100]	validation-auc:0.85382
# [101]	validation-auc:0.85410
# [102]	validation-auc:0.85408
# [103]	validation-auc:0.85365
# [104]	validation-auc:0.85332
# [105]	validation-auc:0.85336
# [106]	validation-auc:0.85344
# [107]	validation-auc:0.85357
# [108]	validation-auc:0.85364
# [109]	validation-auc:0.85351
# [110]	validation-auc:0.85352
# [111]	validation-auc:0.85335
# [112]	validation-auc:0.85308
# [113]	validation-auc:0.85306
# [114]	validation-auc:0.85323
# [115]	validation-auc:0.85322
# [116]	validation-auc:0.85313
# [117]	validation-auc:0.85294
# [118]	validation-auc:0.85307
# [119]	validation-auc:0.85316
# [120]	validation-auc:0.85357
# [121]	validation-auc:0.85353
# [122]	validation-auc:0.85354
# [123]	validation-auc:0.85375
# [124]	validation-auc:0.85359
# [125]	validation-auc:0.85355
# [126]	validation-auc:0.85326
# [127]	validation-auc:0.85329
# [128]	validation-auc:0.85309
# [129]	validation-auc:0.85300
# [0]	validation-auc:0.77863
# [1]	validation-auc:0.79038
# [2]	validation-auc:0.79310
# [3]	validation-auc:0.79860
# [4]	validation-auc:0.80576
# [5]	validation-auc:0.81015
# [6]	validation-auc:0.81557
# [7]	validation-auc:0.81663
# [8]	validation-auc:0.81909
# [9]	validation-auc:0.82342
# [10]	validation-auc:0.82590
# [11]	validation-auc:0.82751
# [12]	validation-auc:0.82817
# [13]	validation-auc:0.82954
# [14]	validation-auc:0.83097
# [15]	validation-auc:0.83283
# [16]	validation-auc:0.83354
# [17]	validation-auc:0.83544
# [18]	validation-auc:0.83501
# [19]	validation-auc:0.83550
# [20]	validation-auc:0.83484
# [21]	validation-auc:0.83547
# [22]	validation-auc:0.83486
# [23]	validation-auc:0.83457
# [24]	validation-auc:0.83522
# [25]	validation-auc:0.83631
# [26]	validation-auc:0.83611
# [27]	validation-auc:0.83630
# [28]	validation-auc:0.83593
# [29]	validation-auc:0.83744
# [30]	validation-auc:0.83711
# [31]	validation-auc:0.83771
# [32]	validation-auc:0.83767
# [33]	validation-auc:0.83780
# [34]	validation-auc:0.83852
# [35]	validation-auc:0.83868
# [36]	validation-auc:0.83854
# [37]	validation-auc:0.83866
# [38]	validation-auc:0.83913
# [39]	validation-auc:0.83939
# [40]	validation-auc:0.83878
# [41]	validation-auc:0.83845
# [42]	validation-auc:0.83861
# [43]	validation-auc:0.83831
# [44]	validation-auc:0.83843
# [45]	validation-auc:0.83894
# [46]	validation-auc:0.83878
# [47]	validation-auc:0.83908
# [48]	validation-auc:0.83868
# [49]	validation-auc:0.83909
# [50]	validation-auc:0.83912
# [51]	validation-auc:0.83842
# [52]	validation-auc:0.83870
# [53]	validation-auc:0.83884
# [54]	validation-auc:0.83851
# [55]	validation-auc:0.83875
# [56]	validation-auc:0.83888
# [57]	validation-auc:0.83914
# [58]	validation-auc:0.83837
# [59]	validation-auc:0.83861
# [60]	validation-auc:0.83802
# [61]	validation-auc:0.83750
# [62]	validation-auc:0.83773
# [63]	validation-auc:0.83759
# [64]	validation-auc:0.83743
# [65]	validation-auc:0.83787
# [66]	validation-auc:0.83756
# [67]	validation-auc:0.83738
# [68]	validation-auc:0.83725
# [69]	validation-auc:0.83734
# [70]	validation-auc:0.83723
# [71]	validation-auc:0.83735
# [72]	validation-auc:0.83672
# [73]	validation-auc:0.83655
# [74]	validation-auc:0.83661
# [75]	validation-auc:0.83600
# [76]	validation-auc:0.83575
# [77]	validation-auc:0.83590
# [78]	validation-auc:0.83559
# [79]	validation-auc:0.83532
# [80]	validation-auc:0.83509
# [81]	validation-auc:0.83491
# [82]	validation-auc:0.83521
# [83]	validation-auc:0.83501
# [84]	validation-auc:0.83478
# [85]	validation-auc:0.83464
# [86]	validation-auc:0.83467
# [87]	validation-auc:0.83412
# [88]	validation-auc:0.83419
# [89]	validation-auc:0.83428
# [0]	validation-auc:0.78374
# [1]	validation-auc:0.80481
# [2]	validation-auc:0.82154
# [3]	validation-auc:0.81719
# [4]	validation-auc:0.81311
# [5]	validation-auc:0.81612
# [6]	validation-auc:0.81718
# [7]	validation-auc:0.81440
# [8]	validation-auc:0.81385
# [9]	validation-auc:0.81451
# [10]	validation-auc:0.81305
# [11]	validation-auc:0.81013
# [12]	validation-auc:0.81051
# [13]	validation-auc:0.81147
# [14]	validation-auc:0.81138
# [15]	validation-auc:0.81073
# [16]	validation-auc:0.80942
# [17]	validation-auc:0.80780
# [18]	validation-auc:0.80999
# [19]	validation-auc:0.80915
# [20]	validation-auc:0.81046
# [21]	validation-auc:0.81350
# [22]	validation-auc:0.81165
# [23]	validation-auc:0.80954
# [24]	validation-auc:0.81007
# [25]	validation-auc:0.80983
# [26]	validation-auc:0.80815
# [27]	validation-auc:0.80597
# [28]	validation-auc:0.80461
# [29]	validation-auc:0.80573
# [30]	validation-auc:0.80520
# [31]	validation-auc:0.80493
# [32]	validation-auc:0.80355
# [33]	validation-auc:0.80169
# [34]	validation-auc:0.80066
# [35]	validation-auc:0.80199
# [36]	validation-auc:0.80200
# [37]	validation-auc:0.80386
# [38]	validation-auc:0.80486
# [39]	validation-auc:0.80453
# [40]	validation-auc:0.80387
# [41]	validation-auc:0.80243
# [42]	validation-auc:0.80409
# [43]	validation-auc:0.80377
# [44]	validation-auc:0.80290
# [45]	validation-auc:0.80353
# [46]	validation-auc:0.80273
# [47]	validation-auc:0.80203
# [48]	validation-auc:0.80201
# [49]	validation-auc:0.80243
# [50]	validation-auc:0.80171
# [51]	validation-auc:0.80307
# [52]	validation-auc:0.80398
# [0]	validation-auc:0.77782
# [1]	validation-auc:0.80632
# [2]	validation-auc:0.81946
# [3]	validation-auc:0.82218
# [4]	validation-auc:0.82557
# [5]	validation-auc:0.82758
# [6]	validation-auc:0.82844
# [7]	validation-auc:0.83076
# [8]	validation-auc:0.82950
# [9]	validation-auc:0.83103
# [10]	validation-auc:0.83214
# [11]	validation-auc:0.83146
# [12]	validation-auc:0.82866
# [13]	validation-auc:0.82737
# [14]	validation-auc:0.82746
# [15]	validation-auc:0.82448
# [16]	validation-auc:0.82420
# [17]	validation-auc:0.82556
# [18]	validation-auc:0.82541
# [19]	validation-auc:0.82614
# [20]	validation-auc:0.82641
# [21]	validation-auc:0.82786
# [22]	validation-auc:0.82658
# [23]	validation-auc:0.82588
# [24]	validation-auc:0.82347
# [25]	validation-auc:0.82354
# [26]	validation-auc:0.82360
# [27]	validation-auc:0.82429
# [28]	validation-auc:0.82319
# [29]	validation-auc:0.82405
# [30]	validation-auc:0.82333
# [31]	validation-auc:0.82156
# [32]	validation-auc:0.81960
# [33]	validation-auc:0.82060
# [34]	validation-auc:0.82019
# [35]	validation-auc:0.81979
# [36]	validation-auc:0.82039
# [37]	validation-auc:0.81949
# [38]	validation-auc:0.81843
# [39]	validation-auc:0.81844
# [40]	validation-auc:0.81886
# [41]	validation-auc:0.81877
# [42]	validation-auc:0.81965
# [43]	validation-auc:0.81942
# [44]	validation-auc:0.81944
# [45]	validation-auc:0.81863
# [46]	validation-auc:0.81773
# [47]	validation-auc:0.81675
# [48]	validation-auc:0.81662
# [49]	validation-auc:0.81610
# [50]	validation-auc:0.81580
# [51]	validation-auc:0.81598
# [52]	validation-auc:0.81771
# [53]	validation-auc:0.81716
# [54]	validation-auc:0.81859
# [55]	validation-auc:0.81756
# [56]	validation-auc:0.81757
# [57]	validation-auc:0.81726
# [58]	validation-auc:0.81705
# [59]	validation-auc:0.81646
# [60]	validation-auc:0.81674
# [0]	validation-auc:0.77749
# [1]	validation-auc:0.79614
# [2]	validation-auc:0.80478
# [3]	validation-auc:0.81115
# [4]	validation-auc:0.81747
# [5]	validation-auc:0.82317
# [6]	validation-auc:0.82761
# [7]	validation-auc:0.82950
# [8]	validation-auc:0.83006
# [9]	validation-auc:0.83484
# [10]	validation-auc:0.83666
# [11]	validation-auc:0.83794
# [12]	validation-auc:0.83796
# [13]	validation-auc:0.83918
# [14]	validation-auc:0.83991
# [15]	validation-auc:0.84014
# [16]	validation-auc:0.84157
# [17]	validation-auc:0.84190
# [18]	validation-auc:0.84027
# [19]	validation-auc:0.84034
# [20]	validation-auc:0.83995
# [21]	validation-auc:0.84018
# [22]	validation-auc:0.84047
# [23]	validation-auc:0.84039
# [24]	validation-auc:0.84046
# [25]	validation-auc:0.84036
# [26]	validation-auc:0.84033
# [27]	validation-auc:0.84148
# [28]	validation-auc:0.84145
# [29]	validation-auc:0.84148
# [30]	validation-auc:0.84114
# [31]	validation-auc:0.84081
# [32]	validation-auc:0.84023
# [33]	validation-auc:0.83975
# [34]	validation-auc:0.83897
# [35]	validation-auc:0.83944
# [36]	validation-auc:0.83785
# [37]	validation-auc:0.83780
# [38]	validation-auc:0.83808
# [39]	validation-auc:0.83808
# [40]	validation-auc:0.83760
# [41]	validation-auc:0.83819
# [42]	validation-auc:0.83798
# [43]	validation-auc:0.83770
# [44]	validation-auc:0.83804
# [45]	validation-auc:0.83848
# [46]	validation-auc:0.83806
# [47]	validation-auc:0.83753
# [48]	validation-auc:0.83839
# [49]	validation-auc:0.83811
# [50]	validation-auc:0.83825
# [51]	validation-auc:0.83869
# [52]	validation-auc:0.83819
# [53]	validation-auc:0.83790
# [54]	validation-auc:0.83749
# [55]	validation-auc:0.83770
# [56]	validation-auc:0.83745
# [57]	validation-auc:0.83741
# [58]	validation-auc:0.83815
# [59]	validation-auc:0.83880
# [60]	validation-auc:0.83868
# [61]	validation-auc:0.83816
# [62]	validation-auc:0.83747
# [63]	validation-auc:0.83747
# [64]	validation-auc:0.83768
# [65]	validation-auc:0.83742
# [66]	validation-auc:0.83741
# [67]	validation-auc:0.83802
# [0]	validation-auc:0.76141
# [1]	validation-auc:0.78243
# [2]	validation-auc:0.79082
# [3]	validation-auc:0.79350
# [4]	validation-auc:0.79921
# [5]	validation-auc:0.80062
# [6]	validation-auc:0.80507
# [7]	validation-auc:0.80478
# [8]	validation-auc:0.80882
# [9]	validation-auc:0.81072
# [10]	validation-auc:0.81259
# [11]	validation-auc:0.81456
# [12]	validation-auc:0.81649
# [13]	validation-auc:0.81822
# [14]	validation-auc:0.81940
# [15]	validation-auc:0.81949
# [16]	validation-auc:0.81989
# [17]	validation-auc:0.82004
# [18]	validation-auc:0.82073
# [19]	validation-auc:0.82149
# [20]	validation-auc:0.82317
# [21]	validation-auc:0.82388
# [22]	validation-auc:0.82410
# [23]	validation-auc:0.82316
# [24]	validation-auc:0.82398
# [25]	validation-auc:0.82440
# [26]	validation-auc:0.82414
# [27]	validation-auc:0.82470
# [28]	validation-auc:0.82502
# [29]	validation-auc:0.82486
# [30]	validation-auc:0.82574
# [31]	validation-auc:0.82659
# [32]	validation-auc:0.82738
# [33]	validation-auc:0.82787
# [34]	validation-auc:0.82811
# [35]	validation-auc:0.82828
# [36]	validation-auc:0.82822
# [37]	validation-auc:0.82779
# [38]	validation-auc:0.82700
# [39]	validation-auc:0.82678
# [40]	validation-auc:0.82799
# [41]	validation-auc:0.82803
# [42]	validation-auc:0.82803
# [43]	validation-auc:0.82765
# [44]	validation-auc:0.82750
# [45]	validation-auc:0.82768
# [46]	validation-auc:0.82756
# [47]	validation-auc:0.82811
# [48]	validation-auc:0.82824
# [49]	validation-auc:0.82824
# [50]	validation-auc:0.82783
# [51]	validation-auc:0.82749
# [52]	validation-auc:0.82738
# [53]	validation-auc:0.82717
# [54]	validation-auc:0.82714
# [55]	validation-auc:0.82690
# [56]	validation-auc:0.82686
# [57]	validation-auc:0.82675
# [58]	validation-auc:0.82770
# [59]	validation-auc:0.82743
# [60]	validation-auc:0.82790
# [61]	validation-auc:0.82804
# [62]	validation-auc:0.82840
# [63]	validation-auc:0.82863
# [64]	validation-auc:0.82834
# [65]	validation-auc:0.82852
# [66]	validation-auc:0.82852
# [67]	validation-auc:0.82843
# [68]	validation-auc:0.82865
# [69]	validation-auc:0.82884
# [70]	validation-auc:0.82901
# [71]	validation-auc:0.82958
# [72]	validation-auc:0.82912
# [73]	validation-auc:0.82892
# [74]	validation-auc:0.82920
# [75]	validation-auc:0.82911
# [76]	validation-auc:0.82912
# [77]	validation-auc:0.82901
# [78]	validation-auc:0.82842
# [79]	validation-auc:0.82852
# [80]	validation-auc:0.82832
# [81]	validation-auc:0.82772
# [82]	validation-auc:0.82797
# [83]	validation-auc:0.82785
# [84]	validation-auc:0.82845
# [85]	validation-auc:0.82848
# [86]	validation-auc:0.82836
# [87]	validation-auc:0.82826
# [88]	validation-auc:0.82835
# [89]	validation-auc:0.82820
# [90]	validation-auc:0.82810
# [91]	validation-auc:0.82836
# [92]	validation-auc:0.82827
# [93]	validation-auc:0.82822
# [94]	validation-auc:0.82817
# [95]	validation-auc:0.82836
# [96]	validation-auc:0.82821
# [97]	validation-auc:0.82835
# [98]	validation-auc:0.82817
# [99]	validation-auc:0.82809
# [100]	validation-auc:0.82806
# [101]	validation-auc:0.82770
# [102]	validation-auc:0.82793
# [103]	validation-auc:0.82781
# [104]	validation-auc:0.82754
# [105]	validation-auc:0.82765
# [106]	validation-auc:0.82754
# [107]	validation-auc:0.82767
# [108]	validation-auc:0.82778
# [109]	validation-auc:0.82812
# [110]	validation-auc:0.82840
# [111]	validation-auc:0.82811
# [112]	validation-auc:0.82852
# [113]	validation-auc:0.82865
# [114]	validation-auc:0.82864
# [115]	validation-auc:0.82846
# [116]	validation-auc:0.82834
# [117]	validation-auc:0.82840
# [118]	validation-auc:0.82832
# [119]	validation-auc:0.82832
# [120]	validation-auc:0.82825
# [121]	validation-auc:0.82811
# [0]	validation-auc:0.78268
# [1]	validation-auc:0.80242
# [2]	validation-auc:0.79731
# [3]	validation-auc:0.79896
# [4]	validation-auc:0.79923
# [5]	validation-auc:0.79934
# [6]	validation-auc:0.80323
# [7]	validation-auc:0.80152
# [8]	validation-auc:0.79957
# [9]	validation-auc:0.79556
# [10]	validation-auc:0.79281
# [11]	validation-auc:0.79679
# [12]	validation-auc:0.79606
# [13]	validation-auc:0.79306
# [14]	validation-auc:0.79376
# [15]	validation-auc:0.79246
# [16]	validation-auc:0.79551
# [17]	validation-auc:0.79704
# [18]	validation-auc:0.79869
# [19]	validation-auc:0.80086
# [20]	validation-auc:0.79831
# [21]	validation-auc:0.79901
# [22]	validation-auc:0.79872
# [23]	validation-auc:0.79947
# [24]	validation-auc:0.80032
# [25]	validation-auc:0.80145
# [26]	validation-auc:0.80102
# [27]	validation-auc:0.79993
# [28]	validation-auc:0.80351
# [29]	validation-auc:0.80242
# [30]	validation-auc:0.80338
# [31]	validation-auc:0.80033
# [32]	validation-auc:0.80262
# [33]	validation-auc:0.80234
# [34]	validation-auc:0.80191
# [35]	validation-auc:0.80036
# [36]	validation-auc:0.80114
# [37]	validation-auc:0.80115
# [38]	validation-auc:0.80124
# [39]	validation-auc:0.80149
# [40]	validation-auc:0.80073
# [41]	validation-auc:0.80187
# [42]	validation-auc:0.80269
# [43]	validation-auc:0.80237
# [44]	validation-auc:0.80191
# [45]	validation-auc:0.80292
# [46]	validation-auc:0.80162
# [47]	validation-auc:0.80157
# [48]	validation-auc:0.80174
# [49]	validation-auc:0.80108
# [50]	validation-auc:0.79946
# [51]	validation-auc:0.80053
# [52]	validation-auc:0.80145
# [53]	validation-auc:0.80078
# [54]	validation-auc:0.80094
# [55]	validation-auc:0.80251
# [56]	validation-auc:0.80293
# [57]	validation-auc:0.80282
# [58]	validation-auc:0.80321
# [59]	validation-auc:0.80216
# [60]	validation-auc:0.80314
# [61]	validation-auc:0.80225
# [62]	validation-auc:0.80248
# [63]	validation-auc:0.80282
# [64]	validation-auc:0.80425
# [65]	validation-auc:0.80378
# [66]	validation-auc:0.80394
# [67]	validation-auc:0.80389
# [68]	validation-auc:0.80411
# [69]	validation-auc:0.80442
# [70]	validation-auc:0.80521
# [71]	validation-auc:0.80452
# [72]	validation-auc:0.80431
# [73]	validation-auc:0.80397
# [74]	validation-auc:0.80513
# [75]	validation-auc:0.80493
# [76]	validation-auc:0.80515
# [77]	validation-auc:0.80423
# [78]	validation-auc:0.80472
# [79]	validation-auc:0.80546
# [80]	validation-auc:0.80422
# [81]	validation-auc:0.80433
# [82]	validation-auc:0.80509
# [83]	validation-auc:0.80543
# [84]	validation-auc:0.80535
# [85]	validation-auc:0.80572
# [86]	validation-auc:0.80562
# [87]	validation-auc:0.80476
# [88]	validation-auc:0.80594
# [89]	validation-auc:0.80561
# [90]	validation-auc:0.80547
# [91]	validation-auc:0.80604
# [92]	validation-auc:0.80601
# [93]	validation-auc:0.80608
# [94]	validation-auc:0.80593
# [95]	validation-auc:0.80601
# [96]	validation-auc:0.80670
# [97]	validation-auc:0.80599
# [98]	validation-auc:0.80745
# [99]	validation-auc:0.80663
# [100]	validation-auc:0.80687
# [101]	validation-auc:0.80698
# [102]	validation-auc:0.80689
# ...
# [0]	validation-auc:0.78124
# [1]	validation-auc:0.80895
# [2]	validation-auc:0.82141
# [3]	validation-auc:0.82306
# [4]	validation-auc:0.82283
# [5]	validation-auc:0.83041
# [6]	validation-auc:0.83081
# [7]	validation-auc:0.83068
# [8]	validation-auc:0.83270
# [9]	validation-auc:0.83287
# [10]	validation-auc:0.83353
# [11]	validation-auc:0.83423
# [12]	validation-auc:0.83347
# [13]	validation-auc:0.83376
# [14]	validation-auc:0.83178
# [15]	validation-auc:0.83159
# [16]	validation-auc:0.82828
# [17]	validation-auc:0.82714
# [18]	validation-auc:0.82868
# [19]	validation-auc:0.82827
# [20]	validation-auc:0.82868
# [21]	validation-auc:0.82817
# [22]	validation-auc:0.82913
# [23]	validation-auc:0.82844
# [24]	validation-auc:0.82825
# [25]	validation-auc:0.82760
# [26]	validation-auc:0.82547
# [27]	validation-auc:0.82538
# [28]	validation-auc:0.82496
# [29]	validation-auc:0.82293
# [30]	validation-auc:0.82340
# [31]	validation-auc:0.82368
# [32]	validation-auc:0.82204
# [33]	validation-auc:0.82183
# [34]	validation-auc:0.82113
# [35]	validation-auc:0.82135
# [36]	validation-auc:0.81915
# [37]	validation-auc:0.81976
# [38]	validation-auc:0.81936
# [39]	validation-auc:0.82088
# [40]	validation-auc:0.82056
# [41]	validation-auc:0.82086
# [42]	validation-auc:0.81992
# [43]	validation-auc:0.81806
# [44]	validation-auc:0.81898
# [45]	validation-auc:0.81974
# [46]	validation-auc:0.81926
# [47]	validation-auc:0.81956
# [48]	validation-auc:0.81948
# [49]	validation-auc:0.81992
# [50]	validation-auc:0.81966
# [51]	validation-auc:0.81924
# [52]	validation-auc:0.81769
# [53]	validation-auc:0.81722
# [54]	validation-auc:0.81805
# [55]	validation-auc:0.81872
# [56]	validation-auc:0.81997
# [57]	validation-auc:0.82157
# [58]	validation-auc:0.82156
# [59]	validation-auc:0.82113
# [60]	validation-auc:0.82081
# [0]	validation-auc:0.78863
# [1]	validation-auc:0.80918
# [2]	validation-auc:0.81999
# [3]	validation-auc:0.82535
# [4]	validation-auc:0.82915
# [5]	validation-auc:0.82993
# [6]	validation-auc:0.83167
# [7]	validation-auc:0.83115
# [8]	validation-auc:0.83344
# [9]	validation-auc:0.83546
# [10]	validation-auc:0.83533
# [11]	validation-auc:0.83360
# [12]	validation-auc:0.83267
# [13]	validation-auc:0.83148
# [14]	validation-auc:0.83056
# [15]	validation-auc:0.83206
# [16]	validation-auc:0.83191
# [17]	validation-auc:0.83281
# [18]	validation-auc:0.83121
# [19]	validation-auc:0.83147
# [20]	validation-auc:0.83054
# [21]	validation-auc:0.83135
# [22]	validation-auc:0.83090
# [23]	validation-auc:0.82930
# [24]	validation-auc:0.82934
# [25]	validation-auc:0.82896
# [26]	validation-auc:0.82756
# [27]	validation-auc:0.82813
# [28]	validation-auc:0.82730
# [29]	validation-auc:0.82618
# [30]	validation-auc:0.82531
# [31]	validation-auc:0.82560
# [32]	validation-auc:0.82563
# [33]	validation-auc:0.82622
# [34]	validation-auc:0.82689
# [35]	validation-auc:0.82712
# [36]	validation-auc:0.82638
# [37]	validation-auc:0.82642
# [38]	validation-auc:0.82608
# [39]	validation-auc:0.82514
# [40]	validation-auc:0.82508
# [41]	validation-auc:0.82529
# [42]	validation-auc:0.82590
# [43]	validation-auc:0.82488
# [44]	validation-auc:0.82452
# [45]	validation-auc:0.82418
# [46]	validation-auc:0.82366
# [47]	validation-auc:0.82536
# [48]	validation-auc:0.82504
# [49]	validation-auc:0.82507
# [50]	validation-auc:0.82523
# [51]	validation-auc:0.82523
# [52]	validation-auc:0.82527
# [53]	validation-auc:0.82477
# [54]	validation-auc:0.82573
# [55]	validation-auc:0.82542
# [56]	validation-auc:0.82520
# [57]	validation-auc:0.82619
# [58]	validation-auc:0.82567
# [59]	validation-auc:0.82537
# [0]	validation-auc:0.78666
# [1]	validation-auc:0.80795
# [2]	validation-auc:0.81864
# [3]	validation-auc:0.82332
# [4]	validation-auc:0.83104
# [5]	validation-auc:0.83450
# [6]	validation-auc:0.83515
# [7]	validation-auc:0.84106
# [8]	validation-auc:0.84209
# [9]	validation-auc:0.84529
# [10]	validation-auc:0.84491
# [11]	validation-auc:0.84768
# [12]	validation-auc:0.84746
# [13]	validation-auc:0.84724
# [14]	validation-auc:0.84779
# [15]	validation-auc:0.84792
# [16]	validation-auc:0.84798
# [17]	validation-auc:0.84750
# [18]	validation-auc:0.84657
# [19]	validation-auc:0.84584
# [20]	validation-auc:0.84673
# [21]	validation-auc:0.84703
# [22]	validation-auc:0.84803
# [23]	validation-auc:0.84957
# [24]	validation-auc:0.84779
# [25]	validation-auc:0.84673
# [26]	validation-auc:0.84495
# [27]	validation-auc:0.84454
# [28]	validation-auc:0.84415
# [29]	validation-auc:0.84385
# [30]	validation-auc:0.84361
# [31]	validation-auc:0.84400
# [32]	validation-auc:0.84349
# [33]	validation-auc:0.84319
# [34]	validation-auc:0.84308
# [35]	validation-auc:0.84342
# [36]	validation-auc:0.84231
# [37]	validation-auc:0.84302
# [38]	validation-auc:0.84250
# [39]	validation-auc:0.84248
# [40]	validation-auc:0.84256
# [41]	validation-auc:0.84316
# [42]	validation-auc:0.84230
# [43]	validation-auc:0.84200
# [44]	validation-auc:0.84186
# [45]	validation-auc:0.84132
# [46]	validation-auc:0.84092
# [47]	validation-auc:0.84052
# [48]	validation-auc:0.84022
# [49]	validation-auc:0.84101
# [50]	validation-auc:0.83980
# [51]	validation-auc:0.83873
# [52]	validation-auc:0.83758
# [53]	validation-auc:0.83699
# [54]	validation-auc:0.83676
# [55]	validation-auc:0.83677
# [56]	validation-auc:0.83745
# [57]	validation-auc:0.83679
# [58]	validation-auc:0.83676
# [59]	validation-auc:0.83598
# [60]	validation-auc:0.83620
# [61]	validation-auc:0.83636
# [62]	validation-auc:0.83604
# [63]	validation-auc:0.83483
# [64]	validation-auc:0.83471
# [65]	validation-auc:0.83432
# [66]	validation-auc:0.83411
# [67]	validation-auc:0.83400
# [68]	validation-auc:0.83371
# [69]	validation-auc:0.83391
# [70]	validation-auc:0.83400
# [71]	validation-auc:0.83378
# [72]	validation-auc:0.83327
# 100%|██████████| 10/10 [00:37<00:00,  3.74s/trial, best loss: -0.8529970986732769]

# %%
best_result
# Out:
# {'lambda': 0.003600133215338894,
#  'learning_rate': 0.06678718052995648,
#  'max_depth': 83.0,
#  'min_child_weight': 15.94866098332461}

# %%
params = {'lambda': 0.003600133215338894,
    'learning_rate': 0.06678718052995648,
    'max_depth': int(83),
    'min_child_weight': 15.94866098332461,
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'seed': seed}

# %% [markdown]
# ### using this parameters to cross validate the model

# %%
booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=1000,
    evals=[(valid, 'validation')],
    early_stopping_rounds=50
)
# Out:
# [0]	validation-auc:0.78600
# [1]	validation-auc:0.79302
# [2]	validation-auc:0.80521
# [3]	validation-auc:0.81042
# [4]	validation-auc:0.81543
# [5]	validation-auc:0.81861
# [6]	validation-auc:0.81970
# [7]	validation-auc:0.82231
# [8]	validation-auc:0.82675
# [9]	validation-auc:0.82891
# [10]	validation-auc:0.82932
# [11]	validation-auc:0.83009
# [12]	validation-auc:0.83192
# [13]	validation-auc:0.83365
# [14]	validation-auc:0.83454
# [15]	validation-auc:0.83551
# [16]	validation-auc:0.83605
# [17]	validation-auc:0.83603
# [18]	validation-auc:0.83717
# [19]	validation-auc:0.83797
# [20]	validation-auc:0.83871
# [21]	validation-auc:0.83859
# [22]	validation-auc:0.83937
# [23]	validation-auc:0.84106
# [24]	validation-auc:0.84162
# [25]	validation-auc:0.84173
# [26]	validation-auc:0.84229
# [27]	validation-auc:0.84319
# [28]	validation-auc:0.84441
# [29]	validation-auc:0.84463
# [30]	validation-auc:0.84502
# [31]	validation-auc:0.84508
# [32]	validation-auc:0.84539
# [33]	validation-auc:0.84611
# [34]	validation-auc:0.84653
# [35]	validation-auc:0.84741
# [36]	validation-auc:0.84822
# [37]	validation-auc:0.84799
# [38]	validation-auc:0.84871
# [39]	validation-auc:0.84878
# [40]	validation-auc:0.84927
# [41]	validation-auc:0.84922
# [42]	validation-auc:0.85014
# [43]	validation-auc:0.85032
# [44]	validation-auc:0.85036
# [45]	validation-auc:0.85086
# [46]	validation-auc:0.85123
# [47]	validation-auc:0.85165
# [48]	validation-auc:0.85144
# [49]	validation-auc:0.85137
# [50]	validation-auc:0.85183
# [51]	validation-auc:0.85241
# [52]	validation-auc:0.85283
# [53]	validation-auc:0.85294
# [54]	validation-auc:0.85296
# [55]	validation-auc:0.85280
# [56]	validation-auc:0.85281
# [57]	validation-auc:0.85314
# [58]	validation-auc:0.85342
# [59]	validation-auc:0.85378
# [60]	validation-auc:0.85371
# [61]	validation-auc:0.85412
# [62]	validation-auc:0.85411
# [63]	validation-auc:0.85436
# [64]	validation-auc:0.85451
# [65]	validation-auc:0.85478
# [66]	validation-auc:0.85460
# [67]	validation-auc:0.85433
# [68]	validation-auc:0.85458
# [69]	validation-auc:0.85438
# [70]	validation-auc:0.85447
# [71]	validation-auc:0.85460
# [72]	validation-auc:0.85448
# [73]	validation-auc:0.85463
# [74]	validation-auc:0.85462
# [75]	validation-auc:0.85468
# [76]	validation-auc:0.85476
# [77]	validation-auc:0.85479
# [78]	validation-auc:0.85469
# [79]	validation-auc:0.85485
# [80]	validation-auc:0.85476
# [81]	validation-auc:0.85482
# [82]	validation-auc:0.85472
# [83]	validation-auc:0.85449
# [84]	validation-auc:0.85411
# [85]	validation-auc:0.85411
# [86]	validation-auc:0.85420
# [87]	validation-auc:0.85408
# [88]	validation-auc:0.85411
# [89]	validation-auc:0.85397
# [90]	validation-auc:0.85394
# [91]	validation-auc:0.85361
# [92]	validation-auc:0.85317
# [93]	validation-auc:0.85326
# [94]	validation-auc:0.85348
# [95]	validation-auc:0.85358
# [96]	validation-auc:0.85368
# [97]	validation-auc:0.85371
# [98]	validation-auc:0.85372
# [99]	validation-auc:0.85362
# [100]	validation-auc:0.85382
# [101]	validation-auc:0.85410
# [102]	validation-auc:0.85408
# [103]	validation-auc:0.85365
# [104]	validation-auc:0.85332
# [105]	validation-auc:0.85336
# [106]	validation-auc:0.85344
# [107]	validation-auc:0.85357
# [108]	validation-auc:0.85364
# [109]	validation-auc:0.85351
# [110]	validation-auc:0.85352
# [111]	validation-auc:0.85335
# [112]	validation-auc:0.85308
# [113]	validation-auc:0.85306
# [114]	validation-auc:0.85323
# [115]	validation-auc:0.85322
# [116]	validation-auc:0.85313
# [117]	validation-auc:0.85294
# [118]	validation-auc:0.85307
# [119]	validation-auc:0.85316
# [120]	validation-auc:0.85357
# [121]	validation-auc:0.85353
# [122]	validation-auc:0.85354
# [123]	validation-auc:0.85375
# [124]	validation-auc:0.85359
# [125]	validation-auc:0.85355
# [126]	validation-auc:0.85326
# [127]	validation-auc:0.85329
# [128]	validation-auc:0.85309

# %%
predicts= booster.predict(valid)

# %%
predicts
# Out:
# array([0.0537997 , 0.9642597 , 0.11561881, ..., 0.04291559, 0.7999883 ,
#        0.03360595], dtype=float32)

# %% [markdown]
# # Model Management using MlFlow

# %%
def objective(params):

    # With MLflow autologging, hyperparameters and the trained model are automatically logged to MLflow.
    mlflow.xgboost.autolog(disable=True, silent=True)

    with mlflow.start_run():
        mlflow.set_tag("Developer", "Dolapo Adebo")
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        auc = roc_auc_score(y_test, y_pred)
        mlflow.log_metric("auc",auc)

        # log artifact
        # mlflow.log_artifact(f"models/{preprocessor_pipe}", artifact_path="preprocessor")
        
        # # log the model
        mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
    # Set the loss to -1*auc_score so fmin maximizes the auc_score
    return {'loss': -auc, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'lambda': hp.loguniform('lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'seed': seed,
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [0]	validation-auc:0.77697
# [1]	validation-auc:0.79911
# [2]	validation-auc:0.81184
# [3]	validation-auc:0.82273
# [4]	validation-auc:0.82851
# [5]	validation-auc:0.83256
# [6]	validation-auc:0.83648
# [7]	validation-auc:0.83857
# [8]	validation-auc:0.84034
# [9]	validation-auc:0.84107
# [10]	validation-auc:0.84078
# [11]	validation-auc:0.83958
# [12]	validation-auc:0.84087
# [13]	validation-auc:0.84397
# [14]	validation-auc:0.84443
# [15]	validation-auc:0.84474
# [16]	validation-auc:0.84475
# [17]	validation-auc:0.84621
# [18]	validation-auc:0.84622
# [19]	validation-auc:0.84646
# [20]	validation-auc:0.84672
# [21]	validation-auc:0.84807
# [22]	validation-auc:0.84785
# [23]	validation-auc:0.84815
# [24]	validation-auc:0.84806
# [25]	validation-auc:0.84845
# [26]	validation-auc:0.84846
# [27]	validation-auc:0.84785
# [28]	validation-auc:0.84799
# [29]	validation-auc:0.84915
# [30]	validation-auc:0.84890
# [31]	validation-auc:0.84880
# [32]	validation-auc:0.84883
# [33]	validation-auc:0.84799
# [34]	validation-auc:0.84746
# [35]	validation-auc:0.84697
# [36]	validation-auc:0.84694
# [37]	validation-auc:0.84680
# [38]	validation-auc:0.84690
# [39]	validation-auc:0.84599
# [40]	validation-auc:0.84640
# [41]	validation-auc:0.84614
# [42]	validation-auc:0.84588
# [43]	validation-auc:0.84560
# [44]	validation-auc:0.84456
# [45]	validation-auc:0.84407
# [46]	validation-auc:0.84349
# [47]	validation-auc:0.84308
# [48]	validation-auc:0.84232
# [49]	validation-auc:0.84227
# [50]	validation-auc:0.84185
# [51]	validation-auc:0.84171
# [52]	validation-auc:0.84192
# [53]	validation-auc:0.84209
# [54]	validation-auc:0.84164
# [55]	validation-auc:0.84128
# [56]	validation-auc:0.84090
# [57]	validation-auc:0.84101
# [58]	validation-auc:0.84090
# [59]	validation-auc:0.83953
# [60]	validation-auc:0.84031
# [61]	validation-auc:0.83997
# [62]	validation-auc:0.83970
# [63]	validation-auc:0.83959
# [64]	validation-auc:0.83888
# [65]	validation-auc:0.83890
# [66]	validation-auc:0.83843
# [67]	validation-auc:0.83805
# [68]	validation-auc:0.83882
# [69]	validation-auc:0.83881
# [70]	validation-auc:0.83877
# [71]	validation-auc:0.83857
# [72]	validation-auc:0.83903
# [73]	validation-auc:0.83910
# [74]	validation-auc:0.83907
# [75]	validation-auc:0.83969
# [76]	validation-auc:0.83977
# [77]	validation-auc:0.83900
# [78]	validation-auc:0.83935
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]
# 2025/04/10 19:29:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.78716
# [1]	validation-auc:0.80563
# [2]	validation-auc:0.82018
# [3]	validation-auc:0.82704
# [4]	validation-auc:0.83136
# [5]	validation-auc:0.83192
# [6]	validation-auc:0.83677
# [7]	validation-auc:0.84030
# [8]	validation-auc:0.84194
# [9]	validation-auc:0.84360
# [10]	validation-auc:0.84500
# [11]	validation-auc:0.84668
# [12]	validation-auc:0.84420
# [13]	validation-auc:0.84508
# [14]	validation-auc:0.84539
# [15]	validation-auc:0.84584
# [16]	validation-auc:0.84648
# [17]	validation-auc:0.84619
# [18]	validation-auc:0.84614
# [19]	validation-auc:0.84538
# [20]	validation-auc:0.84544
# [21]	validation-auc:0.84470
# [22]	validation-auc:0.84441
# [23]	validation-auc:0.84241
# [24]	validation-auc:0.84268
# [25]	validation-auc:0.84266
# [26]	validation-auc:0.84275
# [27]	validation-auc:0.84169
# [28]	validation-auc:0.84176
# [29]	validation-auc:0.84114
# [30]	validation-auc:0.84120
# [31]	validation-auc:0.84194
# [32]	validation-auc:0.84269
# [33]	validation-auc:0.84291
# [34]	validation-auc:0.84273
# [35]	validation-auc:0.84223
# [36]	validation-auc:0.84209
# [37]	validation-auc:0.84102
# [38]	validation-auc:0.84017
# [39]	validation-auc:0.84011
# [40]	validation-auc:0.84000
# [41]	validation-auc:0.84160
# [42]	validation-auc:0.84090
# [43]	validation-auc:0.84054
# [44]	validation-auc:0.84160
# [45]	validation-auc:0.84096
# [46]	validation-auc:0.84115
# [47]	validation-auc:0.84137
# [48]	validation-auc:0.84178
# [49]	validation-auc:0.84136
# [50]	validation-auc:0.84143
# [51]	validation-auc:0.84112
# [52]	validation-auc:0.84109
# [53]	validation-auc:0.83962
# [54]	validation-auc:0.84033
# [55]	validation-auc:0.84052
# [56]	validation-auc:0.84048
# [57]	validation-auc:0.84000
# [58]	validation-auc:0.83949
# [59]	validation-auc:0.83920
# [60]	validation-auc:0.83899
#  10%|█         | 1/10 [00:03<00:27,  3.07s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.79076
# [1]	validation-auc:0.81211
# [2]	validation-auc:0.82295
# [3]	validation-auc:0.82119
# [4]	validation-auc:0.82095
# [5]	validation-auc:0.82348
# [6]	validation-auc:0.82556
# [7]	validation-auc:0.82376
# [8]	validation-auc:0.82206
# [9]	validation-auc:0.82137
# [10]	validation-auc:0.82177
# [11]	validation-auc:0.81951
# [12]	validation-auc:0.81718
# [13]	validation-auc:0.81540
# [14]	validation-auc:0.81331
# [15]	validation-auc:0.81268
# [16]	validation-auc:0.80999
# [17]	validation-auc:0.81159
# [18]	validation-auc:0.81349
# [19]	validation-auc:0.81451
# [20]	validation-auc:0.81614
# [21]	validation-auc:0.81636
# [22]	validation-auc:0.81768
# [23]	validation-auc:0.81624
# [24]	validation-auc:0.81419
# [25]	validation-auc:0.81338
# [26]	validation-auc:0.81518
# [27]	validation-auc:0.81370
# [28]	validation-auc:0.81520
# [29]	validation-auc:0.81365
# [30]	validation-auc:0.81233
# [31]	validation-auc:0.80990
# [32]	validation-auc:0.80949
# [33]	validation-auc:0.81002
# [34]	validation-auc:0.81067
# [35]	validation-auc:0.81325
# [36]	validation-auc:0.81180
# [37]	validation-auc:0.81066
# [38]	validation-auc:0.80993
# [39]	validation-auc:0.81119
# [40]	validation-auc:0.81182
# [41]	validation-auc:0.81157
# [42]	validation-auc:0.80974
# [43]	validation-auc:0.80875
# [44]	validation-auc:0.80798
# [45]	validation-auc:0.80918
# [46]	validation-auc:0.80856
# [47]	validation-auc:0.80888
# [48]	validation-auc:0.80904
# [49]	validation-auc:0.80947
# [50]	validation-auc:0.80892
# [51]	validation-auc:0.80900
# [52]	validation-auc:0.80899
# [53]	validation-auc:0.80923
# [54]	validation-auc:0.81075
# [55]	validation-auc:0.81157
#  20%|██        | 2/10 [00:06<00:23,  2.98s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.76141
# [1]	validation-auc:0.77686
# [2]	validation-auc:0.79026
# [3]	validation-auc:0.79876
# [4]	validation-auc:0.80253
# [5]	validation-auc:0.80853
# [6]	validation-auc:0.81105
# [7]	validation-auc:0.81490
# [8]	validation-auc:0.81729
# [9]	validation-auc:0.81705
# [10]	validation-auc:0.81719
# [11]	validation-auc:0.81842
# [12]	validation-auc:0.81927
# [13]	validation-auc:0.81818
# [14]	validation-auc:0.81895
# [15]	validation-auc:0.81852
# [16]	validation-auc:0.81845
# [17]	validation-auc:0.81898
# [18]	validation-auc:0.81876
# [19]	validation-auc:0.81862
# [20]	validation-auc:0.81871
# [21]	validation-auc:0.81878
# [22]	validation-auc:0.81921
# [23]	validation-auc:0.81936
# [24]	validation-auc:0.81923
# [25]	validation-auc:0.82060
# [26]	validation-auc:0.82153
# [27]	validation-auc:0.82058
# [28]	validation-auc:0.82113
# [29]	validation-auc:0.82191
# [30]	validation-auc:0.82236
# [31]	validation-auc:0.82275
# [32]	validation-auc:0.82248
# [33]	validation-auc:0.82277
# [34]	validation-auc:0.82306
# [35]	validation-auc:0.82335
# [36]	validation-auc:0.82395
# [37]	validation-auc:0.82391
# [38]	validation-auc:0.82358
# [39]	validation-auc:0.82383
# [40]	validation-auc:0.82371
# [41]	validation-auc:0.82318
# [42]	validation-auc:0.82342
# [43]	validation-auc:0.82360
# [44]	validation-auc:0.82326
# [45]	validation-auc:0.82378
# [46]	validation-auc:0.82390
# [47]	validation-auc:0.82342
# [48]	validation-auc:0.82351
# [49]	validation-auc:0.82361
# [50]	validation-auc:0.82387
# [51]	validation-auc:0.82377
# [52]	validation-auc:0.82408
# [53]	validation-auc:0.82416
# [54]	validation-auc:0.82439
# [55]	validation-auc:0.82471
# [56]	validation-auc:0.82454
# [57]	validation-auc:0.82456
# [58]	validation-auc:0.82397
# [59]	validation-auc:0.82417
# [60]	validation-auc:0.82386
# [61]	validation-auc:0.82397
# [62]	validation-auc:0.82407
# [63]	validation-auc:0.82430
# [64]	validation-auc:0.82407
# [65]	validation-auc:0.82435
# [66]	validation-auc:0.82395
# [67]	validation-auc:0.82433
# [68]	validation-auc:0.82444
# [69]	validation-auc:0.82433
# [70]	validation-auc:0.82368
# [71]	validation-auc:0.82379
# [72]	validation-auc:0.82370
# [73]	validation-auc:0.82350
# [74]	validation-auc:0.82340
# [75]	validation-auc:0.82284
# [76]	validation-auc:0.82312
# [77]	validation-auc:0.82308
# [78]	validation-auc:0.82318
# [79]	validation-auc:0.82365
# [80]	validation-auc:0.82323
# [81]	validation-auc:0.82343
# [82]	validation-auc:0.82352
# [83]	validation-auc:0.82348
# [84]	validation-auc:0.82366
# [85]	validation-auc:0.82388
# [86]	validation-auc:0.82373
# [87]	validation-auc:0.82427
# [88]	validation-auc:0.82431
# [89]	validation-auc:0.82424
# [90]	validation-auc:0.82421
# [91]	validation-auc:0.82471
# [92]	validation-auc:0.82461
# [93]	validation-auc:0.82467
# [94]	validation-auc:0.82451
# [95]	validation-auc:0.82443
# [96]	validation-auc:0.82438
# [97]	validation-auc:0.82481
# [98]	validation-auc:0.82505
# [99]	validation-auc:0.82470
# [100]	validation-auc:0.82479
# [101]	validation-auc:0.82492
# [102]	validation-auc:0.82502
# [103]	validation-auc:0.82528
# [104]	validation-auc:0.82544
# [105]	validation-auc:0.82586
# [106]	validation-auc:0.82617
# [107]	validation-auc:0.82623
# [108]	validation-auc:0.82613
# [109]	validation-auc:0.82628
# [110]	validation-auc:0.82623
# [111]	validation-auc:0.82624
# [112]	validation-auc:0.82656
# [113]	validation-auc:0.82664
# [114]	validation-auc:0.82683
# [115]	validation-auc:0.82679
# [116]	validation-auc:0.82653
# [117]	validation-auc:0.82628
# [118]	validation-auc:0.82687
# [119]	validation-auc:0.82668
# [120]	validation-auc:0.82606
# [121]	validation-auc:0.82616
# [122]	validation-auc:0.82616
# [123]	validation-auc:0.82596
# [124]	validation-auc:0.82565
# [125]	validation-auc:0.82575
# [126]	validation-auc:0.82566
# [127]	validation-auc:0.82573
# [128]	validation-auc:0.82572
# [129]	validation-auc:0.82569
# [130]	validation-auc:0.82547
# [131]	validation-auc:0.82526
# [132]	validation-auc:0.82500
# [133]	validation-auc:0.82492
# [134]	validation-auc:0.82476
# [135]	validation-auc:0.82503
# [136]	validation-auc:0.82493
# [137]	validation-auc:0.82491
# [138]	validation-auc:0.82527
# [139]	validation-auc:0.82525
# [140]	validation-auc:0.82551
# [141]	validation-auc:0.82571
# [142]	validation-auc:0.82579
# [143]	validation-auc:0.82598
# [144]	validation-auc:0.82594
# [145]	validation-auc:0.82585
# [146]	validation-auc:0.82554
# [147]	validation-auc:0.82540
# [148]	validation-auc:0.82540
# [149]	validation-auc:0.82552
# [150]	validation-auc:0.82534
# [151]	validation-auc:0.82549
# [152]	validation-auc:0.82570
# [153]	validation-auc:0.82550
# [154]	validation-auc:0.82546
# [155]	validation-auc:0.82575
# [156]	validation-auc:0.82565
# [157]	validation-auc:0.82566
# [158]	validation-auc:0.82557
# [159]	validation-auc:0.82536
# [160]	validation-auc:0.82528
# [161]	validation-auc:0.82545
# [162]	validation-auc:0.82565
# [163]	validation-auc:0.82558
# [164]	validation-auc:0.82570
# [165]	validation-auc:0.82553
# [166]	validation-auc:0.82517
# [167]	validation-auc:0.82531
#  30%|███       | 3/10 [00:09<00:20,  2.98s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.75724
# [1]	validation-auc:0.76369
# [2]	validation-auc:0.77063
# [3]	validation-auc:0.77061
# [4]	validation-auc:0.77380
# [5]	validation-auc:0.77488
# [6]	validation-auc:0.77318
# [7]	validation-auc:0.77676
# [8]	validation-auc:0.77996
# [9]	validation-auc:0.78294
# [10]	validation-auc:0.78336
# [11]	validation-auc:0.78416
# [12]	validation-auc:0.78534
# [13]	validation-auc:0.78762
# [14]	validation-auc:0.78856
# [15]	validation-auc:0.79062
# [16]	validation-auc:0.79313
# [17]	validation-auc:0.79538
# [18]	validation-auc:0.79758
# [19]	validation-auc:0.79865
# [20]	validation-auc:0.80027
# [21]	validation-auc:0.80158
# [22]	validation-auc:0.80204
# [23]	validation-auc:0.80292
# [24]	validation-auc:0.80417
# [25]	validation-auc:0.80482
# [26]	validation-auc:0.80615
# [27]	validation-auc:0.80663
# [28]	validation-auc:0.80701
# [29]	validation-auc:0.80865
# [30]	validation-auc:0.80902
# [31]	validation-auc:0.80970
# [32]	validation-auc:0.81006
# [33]	validation-auc:0.81083
# [34]	validation-auc:0.81120
# [35]	validation-auc:0.81214
# [36]	validation-auc:0.81272
# [37]	validation-auc:0.81310
# [38]	validation-auc:0.81314
# [39]	validation-auc:0.81352
# [40]	validation-auc:0.81405
# [41]	validation-auc:0.81453
# [42]	validation-auc:0.81539
# [43]	validation-auc:0.81546
# [44]	validation-auc:0.81640
# [45]	validation-auc:0.81646
# [46]	validation-auc:0.81646
# [47]	validation-auc:0.81710
# [48]	validation-auc:0.81776
# [49]	validation-auc:0.81841
# [50]	validation-auc:0.81897
# [51]	validation-auc:0.81970
# [52]	validation-auc:0.82021
# [53]	validation-auc:0.82027
# [54]	validation-auc:0.82071
# [55]	validation-auc:0.82015
# [56]	validation-auc:0.82034
# [57]	validation-auc:0.82006
# [58]	validation-auc:0.82040
# [59]	validation-auc:0.82061
# [60]	validation-auc:0.82104
# [61]	validation-auc:0.82134
# [62]	validation-auc:0.82105
# [63]	validation-auc:0.82136
# [64]	validation-auc:0.82140
# [65]	validation-auc:0.82152
# [66]	validation-auc:0.82166
# [67]	validation-auc:0.82188
# [68]	validation-auc:0.82210
# [69]	validation-auc:0.82217
# [70]	validation-auc:0.82257
# [71]	validation-auc:0.82281
# [72]	validation-auc:0.82303
# [73]	validation-auc:0.82293
# [74]	validation-auc:0.82300
# [75]	validation-auc:0.82306
# [76]	validation-auc:0.82309
# [77]	validation-auc:0.82315
# [78]	validation-auc:0.82321
# [79]	validation-auc:0.82326
# [80]	validation-auc:0.82304
# [81]	validation-auc:0.82326
# [82]	validation-auc:0.82331
# [83]	validation-auc:0.82354
# [84]	validation-auc:0.82380
# [85]	validation-auc:0.82377
# [86]	validation-auc:0.82388
# [87]	validation-auc:0.82394
# [88]	validation-auc:0.82388
# [89]	validation-auc:0.82375
# [90]	validation-auc:0.82389
# [91]	validation-auc:0.82397
# [92]	validation-auc:0.82422
# [93]	validation-auc:0.82381
# [94]	validation-auc:0.82408
# [95]	validation-auc:0.82417
# [96]	validation-auc:0.82429
# [97]	validation-auc:0.82395
# [98]	validation-auc:0.82405
# [99]	validation-auc:0.82395
# [100]	validation-auc:0.82393
# [101]	validation-auc:0.82402
# [102]	validation-auc:0.82426
# [103]	validation-auc:0.82439
# [104]	validation-auc:0.82452
# [105]	validation-auc:0.82424
# [106]	validation-auc:0.82408
# [107]	validation-auc:0.82409
# [108]	validation-auc:0.82419
# [109]	validation-auc:0.82435
# [110]	validation-auc:0.82424
# [111]	validation-auc:0.82437
# [112]	validation-auc:0.82430
# [113]	validation-auc:0.82438
# [114]	validation-auc:0.82450
# [115]	validation-auc:0.82452
# [116]	validation-auc:0.82458
# [117]	validation-auc:0.82464
# [118]	validation-auc:0.82487
# [119]	validation-auc:0.82509
# [120]	validation-auc:0.82491
# [121]	validation-auc:0.82498
# [122]	validation-auc:0.82500
# [123]	validation-auc:0.82511
# [124]	validation-auc:0.82530
# [125]	validation-auc:0.82538
# [126]	validation-auc:0.82540
# [127]	validation-auc:0.82554
# [128]	validation-auc:0.82552
# [129]	validation-auc:0.82584
# [130]	validation-auc:0.82577
# [131]	validation-auc:0.82554
# [132]	validation-auc:0.82568
# [133]	validation-auc:0.82569
# [134]	validation-auc:0.82554
# [135]	validation-auc:0.82554
# [136]	validation-auc:0.82566
# [137]	validation-auc:0.82578
# [138]	validation-auc:0.82593
# [139]	validation-auc:0.82601
# [140]	validation-auc:0.82620
# [141]	validation-auc:0.82642
# [142]	validation-auc:0.82660
# [143]	validation-auc:0.82647
# [144]	validation-auc:0.82661
# [145]	validation-auc:0.82659
# [146]	validation-auc:0.82664
# [147]	validation-auc:0.82676
# [148]	validation-auc:0.82681
# [149]	validation-auc:0.82685
# [150]	validation-auc:0.82686
# [151]	validation-auc:0.82696
# [152]	validation-auc:0.82702
# [153]	validation-auc:0.82701
# [154]	validation-auc:0.82696
# [155]	validation-auc:0.82686
# [156]	validation-auc:0.82692
# [157]	validation-auc:0.82693
# [158]	validation-auc:0.82685
# [159]	validation-auc:0.82681
# [160]	validation-auc:0.82684
# [161]	validation-auc:0.82683
# [162]	validation-auc:0.82692
# [163]	validation-auc:0.82691
# [164]	validation-auc:0.82691
# [165]	validation-auc:0.82678
# [166]	validation-auc:0.82698
# [167]	validation-auc:0.82705
# [168]	validation-auc:0.82722
# [169]	validation-auc:0.82722
# [170]	validation-auc:0.82708
# [171]	validation-auc:0.82714
# [172]	validation-auc:0.82740
# [173]	validation-auc:0.82729
# [174]	validation-auc:0.82746
# [175]	validation-auc:0.82746
# [176]	validation-auc:0.82749
# [177]	validation-auc:0.82737
# [178]	validation-auc:0.82727
# [179]	validation-auc:0.82727
# [180]	validation-auc:0.82718
# [181]	validation-auc:0.82731
# [182]	validation-auc:0.82745
# [183]	validation-auc:0.82747
# [184]	validation-auc:0.82742
# [185]	validation-auc:0.82732
# [186]	validation-auc:0.82727
# [187]	validation-auc:0.82724
# [188]	validation-auc:0.82733
# [189]	validation-auc:0.82735
# [190]	validation-auc:0.82733
# [191]	validation-auc:0.82735
# [192]	validation-auc:0.82735
# [193]	validation-auc:0.82738
# [194]	validation-auc:0.82738
# [195]	validation-auc:0.82736
# [196]	validation-auc:0.82731
# [197]	validation-auc:0.82735
# [198]	validation-auc:0.82746
# [199]	validation-auc:0.82731
# [200]	validation-auc:0.82730
# [201]	validation-auc:0.82722
# [202]	validation-auc:0.82732
# [203]	validation-auc:0.82718
# [204]	validation-auc:0.82723
# [205]	validation-auc:0.82726
# [206]	validation-auc:0.82718
# [207]	validation-auc:0.82718
# [208]	validation-auc:0.82724
# [209]	validation-auc:0.82731
# [210]	validation-auc:0.82730
# [211]	validation-auc:0.82719
# [212]	validation-auc:0.82717
# [213]	validation-auc:0.82722
# [214]	validation-auc:0.82711
# [215]	validation-auc:0.82709
# [216]	validation-auc:0.82703
# [217]	validation-auc:0.82705
# [218]	validation-auc:0.82694
# [219]	validation-auc:0.82704
# [220]	validation-auc:0.82696
# [221]	validation-auc:0.82690
# [222]	validation-auc:0.82689
# [223]	validation-auc:0.82689
# [224]	validation-auc:0.82698
# [225]	validation-auc:0.82698
#  40%|████      | 4/10 [00:13<00:19,  3.25s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.75802
# [1]	validation-auc:0.78393
# [2]	validation-auc:0.79561
# [3]	validation-auc:0.79985
# ...
# [76]	validation-auc:0.83509
# [77]	validation-auc:0.83520
# [78]	validation-auc:0.83510
# [79]	validation-auc:0.83483
# [80]	validation-auc:0.83500
# [81]	validation-auc:0.83450
# [82]	validation-auc:0.83463
# [83]	validation-auc:0.83458
# [84]	validation-auc:0.83465
# [85]	validation-auc:0.83495
# [86]	validation-auc:0.83476
# [87]	validation-auc:0.83500
# [88]	validation-auc:0.83501
# [89]	validation-auc:0.83527
# [90]	validation-auc:0.83515
# [91]	validation-auc:0.83485
# [92]	validation-auc:0.83504
# [93]	validation-auc:0.83488
# [94]	validation-auc:0.83465
# [95]	validation-auc:0.83465
# [96]	validation-auc:0.83482
# [97]	validation-auc:0.83490
# [98]	validation-auc:0.83508
# [99]	validation-auc:0.83506
# [100]	validation-auc:0.83502
# [101]	validation-auc:0.83484
# [102]	validation-auc:0.83458
# [103]	validation-auc:0.83470
# [104]	validation-auc:0.83469
# [105]	validation-auc:0.83506
# [106]	validation-auc:0.83529
# [107]	validation-auc:0.83525
# [108]	validation-auc:0.83526
#  70%|███████   | 7/10 [00:23<00:09,  3.28s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.77779
# [1]	validation-auc:0.79909
# [2]	validation-auc:0.81435
# [3]	validation-auc:0.81838
# [4]	validation-auc:0.82236
# [5]	validation-auc:0.82658
# [6]	validation-auc:0.82816
# [7]	validation-auc:0.82733
# [8]	validation-auc:0.82946
# [9]	validation-auc:0.82859
# [10]	validation-auc:0.83042
# [11]	validation-auc:0.82992
# [12]	validation-auc:0.83064
# [13]	validation-auc:0.83121
# [14]	validation-auc:0.82970
# [15]	validation-auc:0.83062
# [16]	validation-auc:0.82915
# [17]	validation-auc:0.82950
# [18]	validation-auc:0.83069
# [19]	validation-auc:0.83257
# [20]	validation-auc:0.83152
# [21]	validation-auc:0.82996
# [22]	validation-auc:0.83057
# [23]	validation-auc:0.82970
# [24]	validation-auc:0.82862
# [25]	validation-auc:0.82915
# [26]	validation-auc:0.82969
# [27]	validation-auc:0.82920
# [28]	validation-auc:0.82855
# [29]	validation-auc:0.82838
# [30]	validation-auc:0.82923
# [31]	validation-auc:0.82985
# [32]	validation-auc:0.82952
# [33]	validation-auc:0.82948
# [34]	validation-auc:0.82973
# [35]	validation-auc:0.82946
# [36]	validation-auc:0.82993
# [37]	validation-auc:0.83019
# [38]	validation-auc:0.82921
# [39]	validation-auc:0.82950
# [40]	validation-auc:0.82941
# [41]	validation-auc:0.82678
# [42]	validation-auc:0.82762
# [43]	validation-auc:0.82800
# [44]	validation-auc:0.82793
# [45]	validation-auc:0.82741
# [46]	validation-auc:0.82670
# [47]	validation-auc:0.82602
# [48]	validation-auc:0.82629
# [49]	validation-auc:0.82703
# [50]	validation-auc:0.82723
# [51]	validation-auc:0.82731
# [52]	validation-auc:0.82745
# [53]	validation-auc:0.82776
# [54]	validation-auc:0.82745
# [55]	validation-auc:0.82782
# [56]	validation-auc:0.82811
# [57]	validation-auc:0.82932
# [58]	validation-auc:0.82849
# [59]	validation-auc:0.82747
# [60]	validation-auc:0.82807
# [61]	validation-auc:0.82765
# [62]	validation-auc:0.82745
# [63]	validation-auc:0.82771
# [64]	validation-auc:0.82767
# [65]	validation-auc:0.82812
# [66]	validation-auc:0.82812
# [67]	validation-auc:0.82814
# [68]	validation-auc:0.82862
# [69]	validation-auc:0.82853
#  80%|████████  | 8/10 [00:26<00:06,  3.26s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [0]	validation-auc:0.77697
# [1]	validation-auc:0.80212
# [2]	validation-auc:0.81103
# [3]	validation-auc:0.82206
# [4]	validation-auc:0.82742
# [5]	validation-auc:0.83150
# [6]	validation-auc:0.83459
# [7]	validation-auc:0.83603
# [8]	validation-auc:0.83790
# [9]	validation-auc:0.83982
# [10]	validation-auc:0.84138
# [11]	validation-auc:0.84324
# [12]	validation-auc:0.84365
# [13]	validation-auc:0.84522
# [14]	validation-auc:0.84636
# [15]	validation-auc:0.84683
# [16]	validation-auc:0.84620
# [17]	validation-auc:0.84754
# [18]	validation-auc:0.84672
# [19]	validation-auc:0.84725
# [20]	validation-auc:0.84831
# [21]	validation-auc:0.84917
# [22]	validation-auc:0.84821
# [23]	validation-auc:0.84896
# [24]	validation-auc:0.84869
# [25]	validation-auc:0.84861
# [26]	validation-auc:0.84896
# [27]	validation-auc:0.84943
# [28]	validation-auc:0.84917
# [29]	validation-auc:0.84924
# [30]	validation-auc:0.84975
# [31]	validation-auc:0.84910
# [32]	validation-auc:0.84956
# [33]	validation-auc:0.84950
# [34]	validation-auc:0.84893
# [35]	validation-auc:0.84821
# [36]	validation-auc:0.84818
# [37]	validation-auc:0.84813
# [38]	validation-auc:0.84868
# [39]	validation-auc:0.84939
# [40]	validation-auc:0.84974
# [41]	validation-auc:0.84910
# [42]	validation-auc:0.84884
# [43]	validation-auc:0.84854
# [44]	validation-auc:0.84924
# [45]	validation-auc:0.84900
# [46]	validation-auc:0.84934
# [47]	validation-auc:0.84895
# [48]	validation-auc:0.84907
# [49]	validation-auc:0.84884
# [50]	validation-auc:0.84836
# [51]	validation-auc:0.84843
# [52]	validation-auc:0.84874
# [53]	validation-auc:0.84915
# [54]	validation-auc:0.84858
# [55]	validation-auc:0.84882
# [56]	validation-auc:0.84831
# [57]	validation-auc:0.84755
# [58]	validation-auc:0.84740
# [59]	validation-auc:0.84795
# [60]	validation-auc:0.84751
# [61]	validation-auc:0.84734
# [62]	validation-auc:0.84697
# [63]	validation-auc:0.84745
# [64]	validation-auc:0.84723
# [65]	validation-auc:0.84690
# [66]	validation-auc:0.84657
# [67]	validation-auc:0.84656
# [68]	validation-auc:0.84656
# [69]	validation-auc:0.84653
# [70]	validation-auc:0.84665
# [71]	validation-auc:0.84618
# [72]	validation-auc:0.84579
# [73]	validation-auc:0.84539
# [74]	validation-auc:0.84533
# [75]	validation-auc:0.84512
# [76]	validation-auc:0.84473
# [77]	validation-auc:0.84449
# [78]	validation-auc:0.84426
# [79]	validation-auc:0.84419
#  90%|█████████ | 9/10 [00:29<00:03,  3.16s/trial, best loss: -0.8396289306404514]
# 2025/04/10 19:29:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 100%|██████████| 10/10 [00:32<00:00,  3.21s/trial, best loss: -0.8440137836492869]

# %% [markdown]
# ### Making predictions using the model saved on MlFlow

# %%
logged_model = 'runs:/781cc236d441498abd235a744203b35e/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.xgboost
#   run_id: 781cc236d441498abd235a744203b35e

# %%
xgb_model = mlflow.xgboost.load_model(logged_model)
xgb_model

# %%
predicts= xgb_model.predict(valid)
